# %%
import pandas as pd
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from collections import Counter
import numpy as np
from typing import Tuple, List, Dict
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from matplotlib.dates import DateFormatter
import os
import joblib
from scipy.stats import median_abs_deviation
from skyfield.api import load, EarthSatellite
from datetime import datetime, timezone
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# Data Preparation (Merge TLE, UCS, and SatCat)

# %%
def data_build_pipe(parquet, output_directory, output_filenm):
    df = pd.read_parquet(parquet)
    tle_cols = ['datetime', 'catalog_number']
    df = df.drop_duplicates(subset=tle_cols)

    ucs_df = pd.read_csv(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\UCS-Satellite-Database 5-1-2023.csv',encoding='latin-1')

    with open(r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\CIS_satcat.pkl", 'rb') as f:
        satcat = pickle.load(f, encoding='latin1')
    satcat_df = pd.DataFrame(satcat)

    df['catalog_number'] = df['catalog_number'].astype(int)
    satcat_df['NORAD_CAT_ID'] = satcat_df['NORAD_CAT_ID'].astype(int)

    df = df.merge(
        satcat_df[['NORAD_CAT_ID', 'OBJECT_TYPE', 'SATNAME', 'SITE']], 
        left_on='catalog_number',
        right_on='NORAD_CAT_ID',
        how='left'
    )

    df = df.drop('catalog_number', axis=1)

    df = df.merge(
        ucs_df[['NORAD Number', 'Operator/Owner', 'Users', 'Purpose']], 
        left_on='NORAD_CAT_ID',
        right_on='NORAD Number',
        how='left'
    )

    df = df.drop('NORAD Number', axis=1)
    
    df.to_parquet(os.path.join(output_directory, output_filenm),engine='pyarrow', compression = 'gzip', index =True))

parquets = [r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\DEV_combat_tle_df.parquet',
            r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\DEV_inference_tle_df.parquet',
            r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\DEV_training_tle_df.parquet']
output_filename = ["MODEL_combat_tle_data.parquet",
                   "MODEL_inft_tle_data.parquet",
                   "MODEL_training_tle_data.parquet"]

output_dir = r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC"

#for f,n in zip(parquets, output_filename):
    #data_build_pipe(f, output_dir, n)

# %% [markdown]
# Add Outlier Column to Training Data to use as Test/Train Split and Validation

# %%
df = pd.read_parquet(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\MODEL_training_tle_data.parquet')

# %%
cols = ['inclination','ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']

def calculate_outlier(df, column_nm, threshold = 2, method = 'iqr'):
    z_scores = np.abs((df[column_nm] - df[column_nm].mean())/df[column_nm].std())
    df[f'outlier_{column_nm}'] = (z_scores > threshold).astype(int)

    if method=='iqr':
        # IQR Method returned ~ 2% outlier
        q1 = df[column_nm].quantile(0.25)
        q3 = df[column_nm].quantile(0.75)
        iqr = q3 - q1
        df[f'outlier_{column_nm}'] = ((df[column_nm] < (q1 - 1.5 * iqr)) | (df[column_nm] > (q3 + 1.5 *iqr))).astype(int)
    
    elif method =='zscore':
        # ~ 5% outlier with threshold=2
        z_scores = np.abs((df[column_nm] - df[column_nm].mean())/df[column_nm].std())
        df[f'outlier_{column_nm}'] = (z_scores > threshold).astype(int)

    elif method =='mad':
        #~9% outliers with threshold=2 
        median = df[column_nm].median()
        mad = median_abs_deviation(df[column_nm])
        modified_z = 0.6745 * (df[column_nm] - median) / mad
        df[f'outlier_{column_nm}'] = (abs(modified_z) > threshold).astype(int)

    else:
        print('Not a valid outlier detection method')

    df['outlier'] = (df.iloc[:, -6:] == 1).any(axis=1).astype(int)

count = 0 
tle_df = pd.DataFrame()
for id in df['NORAD_CAT_ID'].unique():
    bysat_df = df[df['NORAD_CAT_ID']==id]
    #print(bysat_df['NORAD_CAT_ID'].unique())
    for c in cols:
        calculate_outlier(bysat_df,c, threshold = 2, method = 'mad')
    tle_df = pd.concat([tle_df, bysat_df], axis=0)
    count += 1
    progress = (count/len(df['NORAD_CAT_ID'].unique())) * 100
    print(f"Outlier calculation is {progress} percent complete")

tle_df.to_parquet(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\model_test_train.parquet',engine='pyarrow', compression = 'gzip', index =True)
# Out:
# Outlier calculation is 0.039308176100628936 percent complete
# Outlier calculation is 0.07861635220125787 percent complete
# Outlier calculation is 0.1179245283018868 percent complete
# Outlier calculation is 0.15723270440251574 percent complete
# Outlier calculation is 0.19654088050314467 percent complete
# Outlier calculation is 0.2358490566037736 percent complete
# Outlier calculation is 0.2751572327044025 percent complete
# Outlier calculation is 0.3144654088050315 percent complete
# Outlier calculation is 0.3537735849056604 percent complete
# Outlier calculation is 0.39308176100628933 percent complete
# Outlier calculation is 0.43238993710691825 percent complete
# Outlier calculation is 0.4716981132075472 percent complete
# Outlier calculation is 0.511006289308176 percent complete
# Outlier calculation is 0.550314465408805 percent complete
# Outlier calculation is 0.589622641509434 percent complete
# Outlier calculation is 0.628930817610063 percent complete
# Outlier calculation is 0.6682389937106918 percent complete
# Outlier calculation is 0.7075471698113208 percent complete
# Outlier calculation is 0.7468553459119497 percent complete
# Outlier calculation is 0.7861635220125787 percent complete
# Outlier calculation is 0.8254716981132075 percent complete
# Outlier calculation is 0.8647798742138365 percent complete
# Outlier calculation is 0.9040880503144654 percent complete
# Outlier calculation is 0.9433962264150944 percent complete
# Outlier calculation is 0.9827044025157232 percent complete
# Outlier calculation is 1.022012578616352 percent complete
# Outlier calculation is 1.0613207547169812 percent complete
# Outlier calculation is 1.10062893081761 percent complete
# Outlier calculation is 1.139937106918239 percent complete
# Outlier calculation is 1.179245283018868 percent complete
# Outlier calculation is 1.2185534591194969 percent complete
# Outlier calculation is 1.257861635220126 percent complete
# Outlier calculation is 1.2971698113207548 percent complete
# Outlier calculation is 1.3364779874213837 percent complete
# Outlier calculation is 1.3757861635220126 percent complete
# Outlier calculation is 1.4150943396226416 percent complete
# Outlier calculation is 1.4544025157232705 percent complete
# Outlier calculation is 1.4937106918238994 percent complete
# Outlier calculation is 1.5330188679245282 percent complete
# Outlier calculation is 1.5723270440251573 percent complete
# Outlier calculation is 1.6116352201257862 percent complete
# Outlier calculation is 1.650943396226415 percent complete
# Outlier calculation is 1.690251572327044 percent complete
# Outlier calculation is 1.729559748427673 percent complete
# Outlier calculation is 1.7688679245283019 percent complete
# Outlier calculation is 1.8081761006289307 percent complete
# Outlier calculation is 1.8474842767295596 percent complete
# Outlier calculation is 1.8867924528301887 percent complete
# Outlier calculation is 1.9261006289308176 percent complete
# Outlier calculation is 1.9654088050314464 percent complete
# Outlier calculation is 2.0047169811320753 percent complete
# Outlier calculation is 2.044025157232704 percent complete
# Outlier calculation is 2.083333333333333 percent complete
# Outlier calculation is 2.1226415094339623 percent complete
# Outlier calculation is 2.161949685534591 percent complete
# Outlier calculation is 2.20125786163522 percent complete
# Outlier calculation is 2.240566037735849 percent complete
# Outlier calculation is 2.279874213836478 percent complete
# Outlier calculation is 2.3191823899371067 percent complete
# Outlier calculation is 2.358490566037736 percent complete
# Outlier calculation is 2.397798742138365 percent complete
# Outlier calculation is 2.4371069182389937 percent complete
# Outlier calculation is 2.4764150943396226 percent complete
# Outlier calculation is 2.515723270440252 percent complete
# Outlier calculation is 2.5550314465408808 percent complete
# Outlier calculation is 2.5943396226415096 percent complete
# Outlier calculation is 2.6336477987421385 percent complete
# Outlier calculation is 2.6729559748427674 percent complete
# Outlier calculation is 2.7122641509433962 percent complete
# Outlier calculation is 2.751572327044025 percent complete
# Outlier calculation is 2.790880503144654 percent complete
# Outlier calculation is 2.8301886792452833 percent complete
# Outlier calculation is 2.869496855345912 percent complete
# Outlier calculation is 2.908805031446541 percent complete
# Outlier calculation is 2.94811320754717 percent complete
# Outlier calculation is 2.9874213836477987 percent complete
# Outlier calculation is 3.0267295597484276 percent complete
# Outlier calculation is 3.0660377358490565 percent complete
# Outlier calculation is 3.1053459119496853 percent complete
# Outlier calculation is 3.1446540880503147 percent complete
# Outlier calculation is 3.1839622641509435 percent complete
# Outlier calculation is 3.2232704402515724 percent complete
# Outlier calculation is 3.2625786163522013 percent complete
# Outlier calculation is 3.30188679245283 percent complete
# Outlier calculation is 3.341194968553459 percent complete
# Outlier calculation is 3.380503144654088 percent complete
# Outlier calculation is 3.4198113207547167 percent complete
# Outlier calculation is 3.459119496855346 percent complete
# Outlier calculation is 3.498427672955975 percent complete
# Outlier calculation is 3.5377358490566038 percent complete
# Outlier calculation is 3.5770440251572326 percent complete
# Outlier calculation is 3.6163522012578615 percent complete
# Outlier calculation is 3.6556603773584904 percent complete
# Outlier calculation is 3.6949685534591192 percent complete
# Outlier calculation is 3.734276729559748 percent complete
# Outlier calculation is 3.7735849056603774 percent complete
# Outlier calculation is 3.8128930817610063 percent complete
# Outlier calculation is 3.852201257861635 percent complete
# Outlier calculation is 3.891509433962264 percent complete
# Outlier calculation is 3.930817610062893 percent complete
# Outlier calculation is 3.9701257861635217 percent complete
# Outlier calculation is 4.009433962264151 percent complete
# Outlier calculation is 4.04874213836478 percent complete
# Outlier calculation is 4.088050314465408 percent complete
# Outlier calculation is 4.127358490566038 percent complete
# Outlier calculation is 4.166666666666666 percent complete
# Outlier calculation is 4.205974842767295 percent complete
# Outlier calculation is 4.245283018867925 percent complete
# Outlier calculation is 4.284591194968553 percent complete
# Outlier calculation is 4.323899371069182 percent complete
# Outlier calculation is 4.363207547169811 percent complete
# Outlier calculation is 4.40251572327044 percent complete
# Outlier calculation is 4.441823899371069 percent complete
# Outlier calculation is 4.481132075471698 percent complete
# Outlier calculation is 4.520440251572326 percent complete
# Outlier calculation is 4.559748427672956 percent complete
# Outlier calculation is 4.599056603773585 percent complete
# Outlier calculation is 4.638364779874213 percent complete
# Outlier calculation is 4.677672955974843 percent complete
# Outlier calculation is 4.716981132075472 percent complete
# Outlier calculation is 4.756289308176101 percent complete
# Outlier calculation is 4.79559748427673 percent complete
# Outlier calculation is 4.834905660377359 percent complete
# Outlier calculation is 4.8742138364779874 percent complete
# Outlier calculation is 4.913522012578617 percent complete
# Outlier calculation is 4.952830188679245 percent complete
# Outlier calculation is 4.9921383647798745 percent complete
# Outlier calculation is 5.031446540880504 percent complete
# Outlier calculation is 5.070754716981132 percent complete
# Outlier calculation is 5.1100628930817615 percent complete
# Outlier calculation is 5.14937106918239 percent complete
# Outlier calculation is 5.188679245283019 percent complete
# Outlier calculation is 5.227987421383648 percent complete
# Outlier calculation is 5.267295597484277 percent complete
# Outlier calculation is 5.306603773584905 percent complete
# Outlier calculation is 5.345911949685535 percent complete
# Outlier calculation is 5.385220125786164 percent complete
# Outlier calculation is 5.4245283018867925 percent complete
# Outlier calculation is 5.463836477987422 percent complete
# Outlier calculation is 5.50314465408805 percent complete
# Outlier calculation is 5.5424528301886795 percent complete
# Outlier calculation is 5.581761006289308 percent complete
# Outlier calculation is 5.621069182389937 percent complete
# Outlier calculation is 5.660377358490567 percent complete
# Outlier calculation is 5.699685534591195 percent complete
# Outlier calculation is 5.738993710691824 percent complete
# Outlier calculation is 5.778301886792453 percent complete
# Outlier calculation is 5.817610062893082 percent complete
# Outlier calculation is 5.8569182389937104 percent complete
# Outlier calculation is 5.89622641509434 percent complete
# Outlier calculation is 5.935534591194969 percent complete
# Outlier calculation is 5.9748427672955975 percent complete
# Outlier calculation is 6.014150943396227 percent complete
# Outlier calculation is 6.053459119496855 percent complete
# Outlier calculation is 6.0927672955974845 percent complete
# Outlier calculation is 6.132075471698113 percent complete
# Outlier calculation is 6.171383647798742 percent complete
# Outlier calculation is 6.210691823899371 percent complete
# Outlier calculation is 6.25 percent complete
# Outlier calculation is 6.289308176100629 percent complete
# Outlier calculation is 6.328616352201258 percent complete
# Outlier calculation is 6.367924528301887 percent complete
# Outlier calculation is 6.4072327044025155 percent complete
# Outlier calculation is 6.446540880503145 percent complete
# Outlier calculation is 6.485849056603773 percent complete
# Outlier calculation is 6.5251572327044025 percent complete
# Outlier calculation is 6.564465408805031 percent complete
# Outlier calculation is 6.60377358490566 percent complete
# Outlier calculation is 6.6430817610062896 percent complete
# Outlier calculation is 6.682389937106918 percent complete
# Outlier calculation is 6.721698113207547 percent complete
# Outlier calculation is 6.761006289308176 percent complete
# Outlier calculation is 6.800314465408805 percent complete
# Outlier calculation is 6.839622641509433 percent complete
# Outlier calculation is 6.878930817610063 percent complete
# Outlier calculation is 6.918238993710692 percent complete
# Outlier calculation is 6.9575471698113205 percent complete
# Outlier calculation is 6.99685534591195 percent complete
# Outlier calculation is 7.036163522012578 percent complete
# Outlier calculation is 7.0754716981132075 percent complete
# Outlier calculation is 7.114779874213836 percent complete
# Outlier calculation is 7.154088050314465 percent complete
# Outlier calculation is 7.193396226415095 percent complete
# Outlier calculation is 7.232704402515723 percent complete
# Outlier calculation is 7.272012578616352 percent complete
# Outlier calculation is 7.311320754716981 percent complete
# Outlier calculation is 7.35062893081761 percent complete
# Outlier calculation is 7.3899371069182385 percent complete
# Outlier calculation is 7.429245283018868 percent complete
# Outlier calculation is 7.468553459119496 percent complete
# Outlier calculation is 7.5078616352201255 percent complete
# Outlier calculation is 7.547169811320755 percent complete
# Outlier calculation is 7.586477987421383 percent complete
# Outlier calculation is 7.6257861635220126 percent complete
# Outlier calculation is 7.665094339622641 percent complete
# Outlier calculation is 7.70440251572327 percent complete
# Outlier calculation is 7.743710691823899 percent complete
# Outlier calculation is 7.783018867924528 percent complete
# Outlier calculation is 7.822327044025156 percent complete
# Outlier calculation is 7.861635220125786 percent complete
# Outlier calculation is 7.900943396226415 percent complete
# Outlier calculation is 7.9402515723270435 percent complete
# Outlier calculation is 7.979559748427673 percent complete
# Outlier calculation is 8.018867924528301 percent complete
# Outlier calculation is 8.05817610062893 percent complete
# Outlier calculation is 8.09748427672956 percent complete
# Outlier calculation is 8.13679245283019 percent complete
# Outlier calculation is 8.176100628930817 percent complete
# Outlier calculation is 8.215408805031446 percent complete
# Outlier calculation is 8.254716981132075 percent complete
# Outlier calculation is 8.294025157232705 percent complete
# Outlier calculation is 8.333333333333332 percent complete
# Outlier calculation is 8.372641509433961 percent complete
# Outlier calculation is 8.41194968553459 percent complete
# Outlier calculation is 8.45125786163522 percent complete
# Outlier calculation is 8.49056603773585 percent complete
# Outlier calculation is 8.529874213836477 percent complete
# Outlier calculation is 8.569182389937106 percent complete
# Outlier calculation is 8.608490566037736 percent complete
# Outlier calculation is 8.647798742138365 percent complete
# Outlier calculation is 8.687106918238992 percent complete
# Outlier calculation is 8.726415094339622 percent complete
# Outlier calculation is 8.765723270440251 percent complete
# Outlier calculation is 8.80503144654088 percent complete
# Outlier calculation is 8.84433962264151 percent complete
# Outlier calculation is 8.883647798742137 percent complete
# Outlier calculation is 8.922955974842766 percent complete
# Outlier calculation is 8.962264150943396 percent complete
# Outlier calculation is 9.001572327044025 percent complete
# Outlier calculation is 9.040880503144653 percent complete
# Outlier calculation is 9.080188679245282 percent complete
# Outlier calculation is 9.119496855345911 percent complete
# Outlier calculation is 9.15880503144654 percent complete
# Outlier calculation is 9.19811320754717 percent complete
# Outlier calculation is 9.237421383647797 percent complete
# Outlier calculation is 9.276729559748427 percent complete
# Outlier calculation is 9.316037735849056 percent complete
# Outlier calculation is 9.355345911949685 percent complete
# Outlier calculation is 9.394654088050315 percent complete
# Outlier calculation is 9.433962264150944 percent complete
# Outlier calculation is 9.473270440251573 percent complete
# Outlier calculation is 9.512578616352203 percent complete
# Outlier calculation is 9.55188679245283 percent complete
# Outlier calculation is 9.59119496855346 percent complete
# Outlier calculation is 9.630503144654089 percent complete
# Outlier calculation is 9.669811320754718 percent complete
# Outlier calculation is 9.709119496855347 percent complete
# Outlier calculation is 9.748427672955975 percent complete
# Outlier calculation is 9.787735849056604 percent complete
# Outlier calculation is 9.827044025157234 percent complete
# Outlier calculation is 9.866352201257863 percent complete
# Outlier calculation is 9.90566037735849 percent complete
# Outlier calculation is 9.94496855345912 percent complete
# Outlier calculation is 9.984276729559749 percent complete
# Outlier calculation is 10.023584905660378 percent complete
# Outlier calculation is 10.062893081761008 percent complete
# Outlier calculation is 10.102201257861635 percent complete
# Outlier calculation is 10.141509433962264 percent complete
# Outlier calculation is 10.180817610062894 percent complete
# Outlier calculation is 10.220125786163523 percent complete
# Outlier calculation is 10.25943396226415 percent complete
# Outlier calculation is 10.29874213836478 percent complete
# Outlier calculation is 10.33805031446541 percent complete
# Outlier calculation is 10.377358490566039 percent complete
# Outlier calculation is 10.416666666666668 percent complete
# Outlier calculation is 10.455974842767295 percent complete
# Outlier calculation is 10.495283018867925 percent complete
# Outlier calculation is 10.534591194968554 percent complete
# Outlier calculation is 10.573899371069183 percent complete
# Outlier calculation is 10.61320754716981 percent complete
# Outlier calculation is 10.65251572327044 percent complete
# Outlier calculation is 10.69182389937107 percent complete
# Outlier calculation is 10.731132075471699 percent complete
# Outlier calculation is 10.770440251572328 percent complete
# Outlier calculation is 10.809748427672956 percent complete
# Outlier calculation is 10.849056603773585 percent complete
# Outlier calculation is 10.888364779874214 percent complete
# Outlier calculation is 10.927672955974844 percent complete
# Outlier calculation is 10.966981132075473 percent complete
# Outlier calculation is 11.0062893081761 percent complete
# Outlier calculation is 11.04559748427673 percent complete
# Outlier calculation is 11.084905660377359 percent complete
# Outlier calculation is 11.124213836477988 percent complete
# Outlier calculation is 11.163522012578616 percent complete
# Outlier calculation is 11.202830188679245 percent complete
# Outlier calculation is 11.242138364779874 percent complete
# Outlier calculation is 11.281446540880504 percent complete
# Outlier calculation is 11.320754716981133 percent complete
# Outlier calculation is 11.36006289308176 percent complete
# Outlier calculation is 11.39937106918239 percent complete
# Outlier calculation is 11.43867924528302 percent complete
# Outlier calculation is 11.477987421383649 percent complete
# Outlier calculation is 11.517295597484276 percent complete
# Outlier calculation is 11.556603773584905 percent complete
# Outlier calculation is 11.595911949685535 percent complete
# Outlier calculation is 11.635220125786164 percent complete
# Outlier calculation is 11.674528301886793 percent complete
# Outlier calculation is 11.713836477987421 percent complete
# Outlier calculation is 11.75314465408805 percent complete
# Outlier calculation is 11.79245283018868 percent complete
# Outlier calculation is 11.831761006289309 percent complete
# Outlier calculation is 11.871069182389938 percent complete
# Outlier calculation is 11.910377358490566 percent complete
# Outlier calculation is 11.949685534591195 percent complete
# Outlier calculation is 11.988993710691824 percent complete
# Outlier calculation is 12.028301886792454 percent complete
# Outlier calculation is 12.067610062893081 percent complete
# Outlier calculation is 12.10691823899371 percent complete
# Outlier calculation is 12.14622641509434 percent complete
# Outlier calculation is 12.185534591194969 percent complete
# Outlier calculation is 12.224842767295598 percent complete
# Outlier calculation is 12.264150943396226 percent complete
# Outlier calculation is 12.303459119496855 percent complete
# Outlier calculation is 12.342767295597485 percent complete
# Outlier calculation is 12.382075471698114 percent complete
# Outlier calculation is 12.421383647798741 percent complete
# Outlier calculation is 12.46069182389937 percent complete
# Outlier calculation is 12.5 percent complete
# Outlier calculation is 12.539308176100631 percent complete
# Outlier calculation is 12.578616352201259 percent complete
# Outlier calculation is 12.617924528301888 percent complete
# Outlier calculation is 12.657232704402515 percent complete
# Outlier calculation is 12.696540880503147 percent complete
# Outlier calculation is 12.735849056603774 percent complete
# Outlier calculation is 12.775157232704403 percent complete
# Outlier calculation is 12.814465408805031 percent complete
# Outlier calculation is 12.853773584905662 percent complete
# Outlier calculation is 12.89308176100629 percent complete
# Outlier calculation is 12.932389937106919 percent complete
# Outlier calculation is 12.971698113207546 percent complete
# Outlier calculation is 13.011006289308177 percent complete
# Outlier calculation is 13.050314465408805 percent complete
# Outlier calculation is 13.089622641509436 percent complete
# Outlier calculation is 13.128930817610062 percent complete
# Outlier calculation is 13.168238993710693 percent complete
# Outlier calculation is 13.20754716981132 percent complete
# Outlier calculation is 13.246855345911952 percent complete
# Outlier calculation is 13.286163522012579 percent complete
# Outlier calculation is 13.325471698113208 percent complete
# Outlier calculation is 13.364779874213836 percent complete
# Outlier calculation is 13.404088050314467 percent complete
# Outlier calculation is 13.443396226415095 percent complete
# Outlier calculation is 13.482704402515724 percent complete
# Outlier calculation is 13.522012578616351 percent complete
# Outlier calculation is 13.561320754716983 percent complete
# Outlier calculation is 13.60062893081761 percent complete
# Outlier calculation is 13.63993710691824 percent complete
# Outlier calculation is 13.679245283018867 percent complete
# Outlier calculation is 13.718553459119498 percent complete
# Outlier calculation is 13.757861635220126 percent complete
# Outlier calculation is 13.797169811320757 percent complete
# Outlier calculation is 13.836477987421384 percent complete
# Outlier calculation is 13.875786163522013 percent complete
# Outlier calculation is 13.915094339622641 percent complete
# Outlier calculation is 13.954402515723272 percent complete
# Outlier calculation is 13.9937106918239 percent complete
# Outlier calculation is 14.033018867924529 percent complete
# Outlier calculation is 14.072327044025156 percent complete
# Outlier calculation is 14.111635220125788 percent complete
# Outlier calculation is 14.150943396226415 percent complete
# Outlier calculation is 14.190251572327044 percent complete
# Outlier calculation is 14.229559748427672 percent complete
# Outlier calculation is 14.268867924528303 percent complete
# Outlier calculation is 14.30817610062893 percent complete
# Outlier calculation is 14.34748427672956 percent complete
# Outlier calculation is 14.38679245283019 percent complete
# Outlier calculation is 14.426100628930818 percent complete
# Outlier calculation is 14.465408805031446 percent complete
# Outlier calculation is 14.504716981132077 percent complete
# Outlier calculation is 14.544025157232705 percent complete
# Outlier calculation is 14.583333333333334 percent complete
# Outlier calculation is 14.622641509433961 percent complete
# Outlier calculation is 14.661949685534593 percent complete
# Outlier calculation is 14.70125786163522 percent complete
# Outlier calculation is 14.74056603773585 percent complete
# Outlier calculation is 14.779874213836477 percent complete
# Outlier calculation is 14.819182389937108 percent complete
# Outlier calculation is 14.858490566037736 percent complete
# Outlier calculation is 14.897798742138365 percent complete
# Outlier calculation is 14.937106918238992 percent complete
# Outlier calculation is 14.976415094339623 percent complete
# Outlier calculation is 15.015723270440251 percent complete
# Outlier calculation is 15.055031446540882 percent complete
# Outlier calculation is 15.09433962264151 percent complete
# Outlier calculation is 15.133647798742139 percent complete
# Outlier calculation is 15.172955974842766 percent complete
# Outlier calculation is 15.212264150943398 percent complete
# Outlier calculation is 15.251572327044025 percent complete
# Outlier calculation is 15.290880503144654 percent complete
# Outlier calculation is 15.330188679245282 percent complete
# Outlier calculation is 15.369496855345913 percent complete
# Outlier calculation is 15.40880503144654 percent complete
# Outlier calculation is 15.44811320754717 percent complete
# Outlier calculation is 15.487421383647797 percent complete
# Outlier calculation is 15.526729559748428 percent complete
# Outlier calculation is 15.566037735849056 percent complete
# Outlier calculation is 15.605345911949687 percent complete
# Outlier calculation is 15.644654088050313 percent complete
# Outlier calculation is 15.683962264150944 percent complete
# Outlier calculation is 15.723270440251572 percent complete
# Outlier calculation is 15.762578616352203 percent complete
# Outlier calculation is 15.80188679245283 percent complete
# Outlier calculation is 15.84119496855346 percent complete
# Outlier calculation is 15.880503144654087 percent complete
# Outlier calculation is 15.919811320754718 percent complete
# Outlier calculation is 15.959119496855346 percent complete
# Outlier calculation is 15.998427672955975 percent complete
# Outlier calculation is 16.037735849056602 percent complete
# Outlier calculation is 16.07704402515723 percent complete
# Outlier calculation is 16.11635220125786 percent complete
# Outlier calculation is 16.15566037735849 percent complete
# Outlier calculation is 16.19496855345912 percent complete
# Outlier calculation is 16.23427672955975 percent complete
# Outlier calculation is 16.27358490566038 percent complete
# Outlier calculation is 16.312893081761008 percent complete
# Outlier calculation is 16.352201257861633 percent complete
# Outlier calculation is 16.391509433962266 percent complete
# Outlier calculation is 16.430817610062892 percent complete
# Outlier calculation is 16.47012578616352 percent complete
# Outlier calculation is 16.50943396226415 percent complete
# Outlier calculation is 16.54874213836478 percent complete
# Outlier calculation is 16.58805031446541 percent complete
# Outlier calculation is 16.62735849056604 percent complete
# Outlier calculation is 16.666666666666664 percent complete
# Outlier calculation is 16.705974842767297 percent complete
# Outlier calculation is 16.745283018867923 percent complete
# Outlier calculation is 16.784591194968552 percent complete
# Outlier calculation is 16.82389937106918 percent complete
# Outlier calculation is 16.86320754716981 percent complete
# Outlier calculation is 16.90251572327044 percent complete
# Outlier calculation is 16.94182389937107 percent complete
# Outlier calculation is 16.9811320754717 percent complete
# Outlier calculation is 17.020440251572328 percent complete
# Outlier calculation is 17.059748427672954 percent complete
# Outlier calculation is 17.099056603773587 percent complete
# Outlier calculation is 17.138364779874212 percent complete
# Outlier calculation is 17.177672955974842 percent complete
# Outlier calculation is 17.21698113207547 percent complete
# Outlier calculation is 17.2562893081761 percent complete
# Outlier calculation is 17.29559748427673 percent complete
# Outlier calculation is 17.33490566037736 percent complete
# Outlier calculation is 17.374213836477985 percent complete
# Outlier calculation is 17.413522012578618 percent complete
# Outlier calculation is 17.452830188679243 percent complete
# Outlier calculation is 17.492138364779876 percent complete
# Outlier calculation is 17.531446540880502 percent complete
# Outlier calculation is 17.57075471698113 percent complete
# Outlier calculation is 17.61006289308176 percent complete
# Outlier calculation is 17.64937106918239 percent complete
# Outlier calculation is 17.68867924528302 percent complete
# Outlier calculation is 17.72798742138365 percent complete
# Outlier calculation is 17.767295597484274 percent complete
# Outlier calculation is 17.806603773584907 percent complete
# Outlier calculation is 17.845911949685533 percent complete
# Outlier calculation is 17.885220125786162 percent complete
# Outlier calculation is 17.92452830188679 percent complete
# Outlier calculation is 17.96383647798742 percent complete
# Outlier calculation is 18.00314465408805 percent complete
# Outlier calculation is 18.04245283018868 percent complete
# Outlier calculation is 18.081761006289305 percent complete
# Outlier calculation is 18.121069182389938 percent complete
# Outlier calculation is 18.160377358490564 percent complete
# Outlier calculation is 18.199685534591197 percent complete
# Outlier calculation is 18.238993710691823 percent complete
# Outlier calculation is 18.278301886792452 percent complete
# Outlier calculation is 18.31761006289308 percent complete
# Outlier calculation is 18.35691823899371 percent complete
# Outlier calculation is 18.39622641509434 percent complete
# Outlier calculation is 18.43553459119497 percent complete
# Outlier calculation is 18.474842767295595 percent complete
# Outlier calculation is 18.514150943396228 percent complete
# Outlier calculation is 18.553459119496853 percent complete
# Outlier calculation is 18.592767295597483 percent complete
# Outlier calculation is 18.632075471698112 percent complete
# Outlier calculation is 18.67138364779874 percent complete
# Outlier calculation is 18.71069182389937 percent complete
# Outlier calculation is 18.75 percent complete
# Outlier calculation is 18.78930817610063 percent complete
# Outlier calculation is 18.82861635220126 percent complete
# Outlier calculation is 18.867924528301888 percent complete
# Outlier calculation is 18.907232704402517 percent complete
# Outlier calculation is 18.946540880503147 percent complete
# Outlier calculation is 18.985849056603772 percent complete
# Outlier calculation is 19.025157232704405 percent complete
# Outlier calculation is 19.06446540880503 percent complete
# Outlier calculation is 19.10377358490566 percent complete
# Outlier calculation is 19.14308176100629 percent complete
# Outlier calculation is 19.18238993710692 percent complete
# Outlier calculation is 19.221698113207548 percent complete
# Outlier calculation is 19.261006289308177 percent complete
# Outlier calculation is 19.300314465408803 percent complete
# Outlier calculation is 19.339622641509436 percent complete
# Outlier calculation is 19.378930817610062 percent complete
# Outlier calculation is 19.418238993710695 percent complete
# Outlier calculation is 19.45754716981132 percent complete
# Outlier calculation is 19.49685534591195 percent complete
# Outlier calculation is 19.53616352201258 percent complete
# Outlier calculation is 19.57547169811321 percent complete
# Outlier calculation is 19.614779874213838 percent complete
# Outlier calculation is 19.654088050314467 percent complete
# Outlier calculation is 19.693396226415093 percent complete
# Outlier calculation is 19.732704402515726 percent complete
# Outlier calculation is 19.77201257861635 percent complete
# Outlier calculation is 19.81132075471698 percent complete
# Outlier calculation is 19.85062893081761 percent complete
# Outlier calculation is 19.88993710691824 percent complete
# Outlier calculation is 19.92924528301887 percent complete
# Outlier calculation is 19.968553459119498 percent complete
# Outlier calculation is 20.007861635220124 percent complete
# Outlier calculation is 20.047169811320757 percent complete
# Outlier calculation is 20.086477987421382 percent complete
# Outlier calculation is 20.125786163522015 percent complete
# Outlier calculation is 20.16509433962264 percent complete
# Outlier calculation is 20.20440251572327 percent complete
# Outlier calculation is 20.2437106918239 percent complete
# Outlier calculation is 20.28301886792453 percent complete
# Outlier calculation is 20.322327044025158 percent complete
# Outlier calculation is 20.361635220125788 percent complete
# Outlier calculation is 20.400943396226413 percent complete
# Outlier calculation is 20.440251572327046 percent complete
# Outlier calculation is 20.479559748427672 percent complete
# Outlier calculation is 20.5188679245283 percent complete
# Outlier calculation is 20.55817610062893 percent complete
# Outlier calculation is 20.59748427672956 percent complete
# Outlier calculation is 20.63679245283019 percent complete
# Outlier calculation is 20.67610062893082 percent complete
# Outlier calculation is 20.715408805031448 percent complete
# Outlier calculation is 20.754716981132077 percent complete
# Outlier calculation is 20.794025157232703 percent complete
# Outlier calculation is 20.833333333333336 percent complete
# Outlier calculation is 20.87264150943396 percent complete
# Outlier calculation is 20.91194968553459 percent complete
# Outlier calculation is 20.95125786163522 percent complete
# Outlier calculation is 20.99056603773585 percent complete
# Outlier calculation is 21.02987421383648 percent complete
# Outlier calculation is 21.069182389937108 percent complete
# Outlier calculation is 21.108490566037734 percent complete
# Outlier calculation is 21.147798742138367 percent complete
# Outlier calculation is 21.187106918238992 percent complete
# Outlier calculation is 21.22641509433962 percent complete
# Outlier calculation is 21.26572327044025 percent complete
# Outlier calculation is 21.30503144654088 percent complete
# Outlier calculation is 21.34433962264151 percent complete
# Outlier calculation is 21.38364779874214 percent complete
# Outlier calculation is 21.42295597484277 percent complete
# Outlier calculation is 21.462264150943398 percent complete
# Outlier calculation is 21.501572327044023 percent complete
# Outlier calculation is 21.540880503144656 percent complete
# Outlier calculation is 21.580188679245282 percent complete
# Outlier calculation is 21.61949685534591 percent complete
# Outlier calculation is 21.65880503144654 percent complete
# Outlier calculation is 21.69811320754717 percent complete
# Outlier calculation is 21.7374213836478 percent complete
# Outlier calculation is 21.77672955974843 percent complete
# Outlier calculation is 21.816037735849054 percent complete
# Outlier calculation is 21.855345911949687 percent complete
# Outlier calculation is 21.894654088050313 percent complete
# Outlier calculation is 21.933962264150946 percent complete
# Outlier calculation is 21.97327044025157 percent complete
# Outlier calculation is 22.0125786163522 percent complete
# Outlier calculation is 22.05188679245283 percent complete
# Outlier calculation is 22.09119496855346 percent complete
# Outlier calculation is 22.13050314465409 percent complete
# Outlier calculation is 22.169811320754718 percent complete
# Outlier calculation is 22.209119496855344 percent complete
# Outlier calculation is 22.248427672955977 percent complete
# Outlier calculation is 22.287735849056602 percent complete
# Outlier calculation is 22.32704402515723 percent complete
# Outlier calculation is 22.36635220125786 percent complete
# Outlier calculation is 22.40566037735849 percent complete
# Outlier calculation is 22.44496855345912 percent complete
# Outlier calculation is 22.48427672955975 percent complete
# Outlier calculation is 22.52358490566038 percent complete
# Outlier calculation is 22.562893081761008 percent complete
# Outlier calculation is 22.602201257861633 percent complete
# Outlier calculation is 22.641509433962266 percent complete
# Outlier calculation is 22.680817610062892 percent complete
# Outlier calculation is 22.72012578616352 percent complete
# Outlier calculation is 22.75943396226415 percent complete
# Outlier calculation is 22.79874213836478 percent complete
# Outlier calculation is 22.83805031446541 percent complete
# Outlier calculation is 22.87735849056604 percent complete
# Outlier calculation is 22.916666666666664 percent complete
# Outlier calculation is 22.955974842767297 percent complete
# Outlier calculation is 22.995283018867923 percent complete
# Outlier calculation is 23.034591194968552 percent complete
# Outlier calculation is 23.07389937106918 percent complete
# Outlier calculation is 23.11320754716981 percent complete
# Outlier calculation is 23.15251572327044 percent complete
# Outlier calculation is 23.19182389937107 percent complete
# Outlier calculation is 23.2311320754717 percent complete
# Outlier calculation is 23.270440251572328 percent complete
# Outlier calculation is 23.309748427672954 percent complete
# Outlier calculation is 23.349056603773587 percent complete
# Outlier calculation is 23.388364779874212 percent complete
# Outlier calculation is 23.427672955974842 percent complete
# Outlier calculation is 23.46698113207547 percent complete
# Outlier calculation is 23.5062893081761 percent complete
# Outlier calculation is 23.54559748427673 percent complete
# Outlier calculation is 23.58490566037736 percent complete
# Outlier calculation is 23.624213836477985 percent complete
# Outlier calculation is 23.663522012578618 percent complete
# Outlier calculation is 23.702830188679243 percent complete
# Outlier calculation is 23.742138364779876 percent complete
# Outlier calculation is 23.781446540880502 percent complete
# Outlier calculation is 23.82075471698113 percent complete
# Outlier calculation is 23.86006289308176 percent complete
# Outlier calculation is 23.89937106918239 percent complete
# Outlier calculation is 23.93867924528302 percent complete
# Outlier calculation is 23.97798742138365 percent complete
# Outlier calculation is 24.017295597484274 percent complete
# Outlier calculation is 24.056603773584907 percent complete
# Outlier calculation is 24.095911949685533 percent complete
# Outlier calculation is 24.135220125786162 percent complete
# Outlier calculation is 24.17452830188679 percent complete
# Outlier calculation is 24.21383647798742 percent complete
# Outlier calculation is 24.25314465408805 percent complete
# Outlier calculation is 24.29245283018868 percent complete
# Outlier calculation is 24.331761006289305 percent complete
# Outlier calculation is 24.371069182389938 percent complete
# Outlier calculation is 24.410377358490564 percent complete
# Outlier calculation is 24.449685534591197 percent complete
# Outlier calculation is 24.488993710691823 percent complete
# Outlier calculation is 24.528301886792452 percent complete
# Outlier calculation is 24.56761006289308 percent complete
# Outlier calculation is 24.60691823899371 percent complete
# Outlier calculation is 24.64622641509434 percent complete
# Outlier calculation is 24.68553459119497 percent complete
# Outlier calculation is 24.724842767295595 percent complete
# Outlier calculation is 24.764150943396228 percent complete
# Outlier calculation is 24.803459119496853 percent complete
# Outlier calculation is 24.842767295597483 percent complete
# Outlier calculation is 24.882075471698112 percent complete
# Outlier calculation is 24.92138364779874 percent complete
# Outlier calculation is 24.96069182389937 percent complete
# Outlier calculation is 25.0 percent complete
# Outlier calculation is 25.039308176100626 percent complete
# Outlier calculation is 25.078616352201262 percent complete
# Outlier calculation is 25.117924528301888 percent complete
# Outlier calculation is 25.157232704402517 percent complete
# Outlier calculation is 25.196540880503143 percent complete
# Outlier calculation is 25.235849056603776 percent complete
# Outlier calculation is 25.275157232704405 percent complete
# Outlier calculation is 25.31446540880503 percent complete
# Outlier calculation is 25.35377358490566 percent complete
# Outlier calculation is 25.393081761006293 percent complete
# Outlier calculation is 25.43238993710692 percent complete
# Outlier calculation is 25.471698113207548 percent complete
# Outlier calculation is 25.511006289308174 percent complete
# Outlier calculation is 25.550314465408807 percent complete
# Outlier calculation is 25.589622641509436 percent complete
# Outlier calculation is 25.628930817610062 percent complete
# Outlier calculation is 25.66823899371069 percent complete
# Outlier calculation is 25.707547169811324 percent complete
# Outlier calculation is 25.74685534591195 percent complete
# Outlier calculation is 25.78616352201258 percent complete
# Outlier calculation is 25.825471698113205 percent complete
# Outlier calculation is 25.864779874213838 percent complete
# Outlier calculation is 25.904088050314467 percent complete
# Outlier calculation is 25.943396226415093 percent complete
# Outlier calculation is 25.982704402515722 percent complete
# Outlier calculation is 26.022012578616355 percent complete
# Outlier calculation is 26.06132075471698 percent complete
# Outlier calculation is 26.10062893081761 percent complete
# Outlier calculation is 26.139937106918236 percent complete
# Outlier calculation is 26.179245283018872 percent complete
# Outlier calculation is 26.218553459119498 percent complete
# Outlier calculation is 26.257861635220124 percent complete
# Outlier calculation is 26.297169811320753 percent complete
# Outlier calculation is 26.336477987421386 percent complete
# Outlier calculation is 26.375786163522015 percent complete
# Outlier calculation is 26.41509433962264 percent complete
# Outlier calculation is 26.45440251572327 percent complete
# Outlier calculation is 26.493710691823903 percent complete
# Outlier calculation is 26.53301886792453 percent complete
# Outlier calculation is 26.572327044025158 percent complete
# Outlier calculation is 26.611635220125784 percent complete
# Outlier calculation is 26.650943396226417 percent complete
# Outlier calculation is 26.690251572327046 percent complete
# Outlier calculation is 26.729559748427672 percent complete
# Outlier calculation is 26.7688679245283 percent complete
# Outlier calculation is 26.808176100628934 percent complete
# Outlier calculation is 26.84748427672956 percent complete
# Outlier calculation is 26.88679245283019 percent complete
# Outlier calculation is 26.926100628930815 percent complete
# Outlier calculation is 26.965408805031448 percent complete
# Outlier calculation is 27.004716981132077 percent complete
# Outlier calculation is 27.044025157232703 percent complete
# Outlier calculation is 27.083333333333332 percent complete
# Outlier calculation is 27.122641509433965 percent complete
# Outlier calculation is 27.16194968553459 percent complete
# Outlier calculation is 27.20125786163522 percent complete
# Outlier calculation is 27.240566037735846 percent complete
# Outlier calculation is 27.27987421383648 percent complete
# Outlier calculation is 27.319182389937108 percent complete
# Outlier calculation is 27.358490566037734 percent complete
# Outlier calculation is 27.397798742138363 percent complete
# Outlier calculation is 27.437106918238996 percent complete
# Outlier calculation is 27.47641509433962 percent complete
# Outlier calculation is 27.51572327044025 percent complete
# Outlier calculation is 27.55503144654088 percent complete
# Outlier calculation is 27.594339622641513 percent complete
# Outlier calculation is 27.63364779874214 percent complete
# Outlier calculation is 27.67295597484277 percent complete
# Outlier calculation is 27.712264150943394 percent complete
# Outlier calculation is 27.751572327044027 percent complete
# Outlier calculation is 27.790880503144656 percent complete
# Outlier calculation is 27.830188679245282 percent complete
# Outlier calculation is 27.86949685534591 percent complete
# Outlier calculation is 27.908805031446544 percent complete
# Outlier calculation is 27.94811320754717 percent complete
# Outlier calculation is 27.9874213836478 percent complete
# Outlier calculation is 28.026729559748425 percent complete
# Outlier calculation is 28.066037735849058 percent complete
# Outlier calculation is 28.105345911949687 percent complete
# Outlier calculation is 28.144654088050313 percent complete
# Outlier calculation is 28.183962264150942 percent complete
# Outlier calculation is 28.223270440251575 percent complete
# Outlier calculation is 28.2625786163522 percent complete
# Outlier calculation is 28.30188679245283 percent complete
# Outlier calculation is 28.341194968553456 percent complete
# Outlier calculation is 28.38050314465409 percent complete
# Outlier calculation is 28.419811320754718 percent complete
# Outlier calculation is 28.459119496855344 percent complete
# Outlier calculation is 28.498427672955973 percent complete
# Outlier calculation is 28.537735849056606 percent complete
# Outlier calculation is 28.57704402515723 percent complete
# Outlier calculation is 28.61635220125786 percent complete
# Outlier calculation is 28.655660377358487 percent complete
# Outlier calculation is 28.69496855345912 percent complete
# Outlier calculation is 28.73427672955975 percent complete
# Outlier calculation is 28.77358490566038 percent complete
# Outlier calculation is 28.812893081761004 percent complete
# Outlier calculation is 28.852201257861637 percent complete
# Outlier calculation is 28.891509433962266 percent complete
# Outlier calculation is 28.930817610062892 percent complete
# Outlier calculation is 28.97012578616352 percent complete
# Outlier calculation is 29.009433962264154 percent complete
# Outlier calculation is 29.04874213836478 percent complete
# Outlier calculation is 29.08805031446541 percent complete
# Outlier calculation is 29.127358490566035 percent complete
# Outlier calculation is 29.166666666666668 percent complete
# Outlier calculation is 29.205974842767297 percent complete
# Outlier calculation is 29.245283018867923 percent complete
# Outlier calculation is 29.284591194968552 percent complete
# Outlier calculation is 29.323899371069185 percent complete
# Outlier calculation is 29.36320754716981 percent complete
# Outlier calculation is 29.40251572327044 percent complete
# Outlier calculation is 29.441823899371066 percent complete
# Outlier calculation is 29.4811320754717 percent complete
# Outlier calculation is 29.520440251572328 percent complete
# Outlier calculation is 29.559748427672954 percent complete
# Outlier calculation is 29.599056603773583 percent complete
# Outlier calculation is 29.638364779874216 percent complete
# Outlier calculation is 29.677672955974842 percent complete
# Outlier calculation is 29.71698113207547 percent complete
# Outlier calculation is 29.756289308176097 percent complete
# Outlier calculation is 29.79559748427673 percent complete
# Outlier calculation is 29.83490566037736 percent complete
# Outlier calculation is 29.874213836477985 percent complete
# Outlier calculation is 29.913522012578614 percent complete
# Outlier calculation is 29.952830188679247 percent complete
# Outlier calculation is 29.992138364779876 percent complete
# Outlier calculation is 30.031446540880502 percent complete
# Outlier calculation is 30.070754716981128 percent complete
# Outlier calculation is 30.110062893081764 percent complete
# Outlier calculation is 30.14937106918239 percent complete
# Outlier calculation is 30.18867924528302 percent complete
# Outlier calculation is 30.227987421383645 percent complete
# Outlier calculation is 30.267295597484278 percent complete
# Outlier calculation is 30.306603773584907 percent complete
# Outlier calculation is 30.345911949685533 percent complete
# Outlier calculation is 30.385220125786162 percent complete
# Outlier calculation is 30.424528301886795 percent complete
# Outlier calculation is 30.46383647798742 percent complete
# Outlier calculation is 30.50314465408805 percent complete
# Outlier calculation is 30.542452830188676 percent complete
# Outlier calculation is 30.58176100628931 percent complete
# Outlier calculation is 30.621069182389938 percent complete
# Outlier calculation is 30.660377358490564 percent complete
# Outlier calculation is 30.699685534591193 percent complete
# Outlier calculation is 30.738993710691826 percent complete
# Outlier calculation is 30.778301886792452 percent complete
# Outlier calculation is 30.81761006289308 percent complete
# Outlier calculation is 30.856918238993707 percent complete
# Outlier calculation is 30.89622641509434 percent complete
# Outlier calculation is 30.93553459119497 percent complete
# Outlier calculation is 30.974842767295595 percent complete
# Outlier calculation is 31.014150943396224 percent complete
# Outlier calculation is 31.053459119496857 percent complete
# Outlier calculation is 31.092767295597483 percent complete
# Outlier calculation is 31.132075471698112 percent complete
# Outlier calculation is 31.171383647798738 percent complete
# Outlier calculation is 31.210691823899374 percent complete
# Outlier calculation is 31.25 percent complete
# Outlier calculation is 31.289308176100626 percent complete
# Outlier calculation is 31.328616352201262 percent complete
# Outlier calculation is 31.367924528301888 percent complete
# Outlier calculation is 31.407232704402517 percent complete
# Outlier calculation is 31.446540880503143 percent complete
# Outlier calculation is 31.485849056603776 percent complete
# Outlier calculation is 31.525157232704405 percent complete
# Outlier calculation is 31.56446540880503 percent complete
# Outlier calculation is 31.60377358490566 percent complete
# Outlier calculation is 31.643081761006293 percent complete
# Outlier calculation is 31.68238993710692 percent complete
# Outlier calculation is 31.721698113207548 percent complete
# Outlier calculation is 31.761006289308174 percent complete
# Outlier calculation is 31.800314465408807 percent complete
# Outlier calculation is 31.839622641509436 percent complete
# Outlier calculation is 31.878930817610062 percent complete
# Outlier calculation is 31.91823899371069 percent complete
# Outlier calculation is 31.957547169811324 percent complete
# Outlier calculation is 31.99685534591195 percent complete
# Outlier calculation is 32.03616352201258 percent complete
# Outlier calculation is 32.075471698113205 percent complete
# Outlier calculation is 32.11477987421384 percent complete
# Outlier calculation is 32.15408805031446 percent complete
# Outlier calculation is 32.193396226415096 percent complete
# Outlier calculation is 32.23270440251572 percent complete
# Outlier calculation is 32.272012578616355 percent complete
# ...
# Outlier calculation is 89.19025157232704 percent complete
# Outlier calculation is 89.22955974842768 percent complete
# Outlier calculation is 89.26886792452831 percent complete
# Outlier calculation is 89.30817610062893 percent complete
# Outlier calculation is 89.34748427672956 percent complete
# Outlier calculation is 89.38679245283019 percent complete
# Outlier calculation is 89.42610062893081 percent complete
# Outlier calculation is 89.46540880503144 percent complete
# Outlier calculation is 89.50471698113208 percent complete
# Outlier calculation is 89.54402515723271 percent complete
# Outlier calculation is 89.58333333333334 percent complete
# Outlier calculation is 89.62264150943396 percent complete
# Outlier calculation is 89.6619496855346 percent complete
# Outlier calculation is 89.70125786163521 percent complete
# Outlier calculation is 89.74056603773585 percent complete
# Outlier calculation is 89.77987421383648 percent complete
# Outlier calculation is 89.8191823899371 percent complete
# Outlier calculation is 89.85849056603774 percent complete
# Outlier calculation is 89.89779874213836 percent complete
# Outlier calculation is 89.937106918239 percent complete
# Outlier calculation is 89.97641509433963 percent complete
# Outlier calculation is 90.01572327044025 percent complete
# Outlier calculation is 90.05503144654088 percent complete
# Outlier calculation is 90.09433962264151 percent complete
# Outlier calculation is 90.13364779874213 percent complete
# Outlier calculation is 90.17295597484278 percent complete
# Outlier calculation is 90.2122641509434 percent complete
# Outlier calculation is 90.25157232704403 percent complete
# Outlier calculation is 90.29088050314465 percent complete
# Outlier calculation is 90.33018867924528 percent complete
# Outlier calculation is 90.36949685534591 percent complete
# Outlier calculation is 90.40880503144653 percent complete
# Outlier calculation is 90.44811320754717 percent complete
# Outlier calculation is 90.4874213836478 percent complete
# Outlier calculation is 90.52672955974843 percent complete
# Outlier calculation is 90.56603773584906 percent complete
# Outlier calculation is 90.60534591194968 percent complete
# Outlier calculation is 90.64465408805032 percent complete
# Outlier calculation is 90.68396226415094 percent complete
# Outlier calculation is 90.72327044025157 percent complete
# Outlier calculation is 90.7625786163522 percent complete
# Outlier calculation is 90.80188679245283 percent complete
# Outlier calculation is 90.84119496855347 percent complete
# Outlier calculation is 90.88050314465409 percent complete
# Outlier calculation is 90.91981132075472 percent complete
# Outlier calculation is 90.95911949685535 percent complete
# Outlier calculation is 90.99842767295597 percent complete
# Outlier calculation is 91.0377358490566 percent complete
# Outlier calculation is 91.07704402515722 percent complete
# Outlier calculation is 91.11635220125787 percent complete
# Outlier calculation is 91.15566037735849 percent complete
# Outlier calculation is 91.19496855345912 percent complete
# Outlier calculation is 91.23427672955975 percent complete
# Outlier calculation is 91.27358490566037 percent complete
# Outlier calculation is 91.312893081761 percent complete
# Outlier calculation is 91.35220125786164 percent complete
# Outlier calculation is 91.39150943396226 percent complete
# Outlier calculation is 91.4308176100629 percent complete
# Outlier calculation is 91.47012578616352 percent complete
# Outlier calculation is 91.50943396226415 percent complete
# Outlier calculation is 91.54874213836479 percent complete
# Outlier calculation is 91.5880503144654 percent complete
# Outlier calculation is 91.62735849056604 percent complete
# Outlier calculation is 91.66666666666666 percent complete
# Outlier calculation is 91.70597484276729 percent complete
# Outlier calculation is 91.74528301886792 percent complete
# Outlier calculation is 91.78459119496856 percent complete
# Outlier calculation is 91.82389937106919 percent complete
# Outlier calculation is 91.86320754716981 percent complete
# Outlier calculation is 91.90251572327044 percent complete
# Outlier calculation is 91.94182389937107 percent complete
# Outlier calculation is 91.98113207547169 percent complete
# Outlier calculation is 92.02044025157232 percent complete
# Outlier calculation is 92.05974842767296 percent complete
# Outlier calculation is 92.09905660377359 percent complete
# Outlier calculation is 92.13836477987421 percent complete
# Outlier calculation is 92.17767295597484 percent complete
# Outlier calculation is 92.21698113207547 percent complete
# Outlier calculation is 92.2562893081761 percent complete
# Outlier calculation is 92.29559748427673 percent complete
# Outlier calculation is 92.33490566037736 percent complete
# Outlier calculation is 92.37421383647799 percent complete
# Outlier calculation is 92.41352201257862 percent complete
# Outlier calculation is 92.45283018867924 percent complete
# Outlier calculation is 92.49213836477988 percent complete
# Outlier calculation is 92.5314465408805 percent complete
# Outlier calculation is 92.57075471698113 percent complete
# Outlier calculation is 92.61006289308176 percent complete
# Outlier calculation is 92.64937106918238 percent complete
# Outlier calculation is 92.68867924528303 percent complete
# Outlier calculation is 92.72798742138365 percent complete
# Outlier calculation is 92.76729559748428 percent complete
# Outlier calculation is 92.80660377358491 percent complete
# Outlier calculation is 92.84591194968553 percent complete
# Outlier calculation is 92.88522012578616 percent complete
# Outlier calculation is 92.9245283018868 percent complete
# Outlier calculation is 92.96383647798741 percent complete
# Outlier calculation is 93.00314465408806 percent complete
# Outlier calculation is 93.04245283018868 percent complete
# Outlier calculation is 93.08176100628931 percent complete
# Outlier calculation is 93.12106918238993 percent complete
# Outlier calculation is 93.16037735849056 percent complete
# Outlier calculation is 93.1996855345912 percent complete
# Outlier calculation is 93.23899371069182 percent complete
# Outlier calculation is 93.27830188679245 percent complete
# Outlier calculation is 93.31761006289308 percent complete
# Outlier calculation is 93.35691823899371 percent complete
# Outlier calculation is 93.39622641509435 percent complete
# Outlier calculation is 93.43553459119497 percent complete
# Outlier calculation is 93.4748427672956 percent complete
# Outlier calculation is 93.51415094339622 percent complete
# Outlier calculation is 93.55345911949685 percent complete
# Outlier calculation is 93.59276729559748 percent complete
# Outlier calculation is 93.63207547169812 percent complete
# Outlier calculation is 93.67138364779875 percent complete
# Outlier calculation is 93.71069182389937 percent complete
# Outlier calculation is 93.75 percent complete
# Outlier calculation is 93.78930817610063 percent complete
# Outlier calculation is 93.82861635220125 percent complete
# Outlier calculation is 93.86792452830188 percent complete
# Outlier calculation is 93.90723270440252 percent complete
# Outlier calculation is 93.94654088050315 percent complete
# Outlier calculation is 93.98584905660378 percent complete
# Outlier calculation is 94.0251572327044 percent complete
# Outlier calculation is 94.06446540880503 percent complete
# Outlier calculation is 94.10377358490565 percent complete
# Outlier calculation is 94.14308176100629 percent complete
# Outlier calculation is 94.18238993710692 percent complete
# Outlier calculation is 94.22169811320755 percent complete
# Outlier calculation is 94.26100628930818 percent complete
# Outlier calculation is 94.3003144654088 percent complete
# Outlier calculation is 94.33962264150944 percent complete
# Outlier calculation is 94.37893081761007 percent complete
# Outlier calculation is 94.41823899371069 percent complete
# Outlier calculation is 94.45754716981132 percent complete
# Outlier calculation is 94.49685534591194 percent complete
# Outlier calculation is 94.53616352201259 percent complete
# Outlier calculation is 94.5754716981132 percent complete
# Outlier calculation is 94.61477987421384 percent complete
# Outlier calculation is 94.65408805031447 percent complete
# Outlier calculation is 94.69339622641509 percent complete
# Outlier calculation is 94.73270440251572 percent complete
# Outlier calculation is 94.77201257861635 percent complete
# Outlier calculation is 94.81132075471697 percent complete
# Outlier calculation is 94.85062893081762 percent complete
# Outlier calculation is 94.88993710691824 percent complete
# Outlier calculation is 94.92924528301887 percent complete
# Outlier calculation is 94.9685534591195 percent complete
# Outlier calculation is 95.00786163522012 percent complete
# Outlier calculation is 95.04716981132076 percent complete
# Outlier calculation is 95.08647798742138 percent complete
# Outlier calculation is 95.12578616352201 percent complete
# Outlier calculation is 95.16509433962264 percent complete
# Outlier calculation is 95.20440251572327 percent complete
# Outlier calculation is 95.2437106918239 percent complete
# Outlier calculation is 95.28301886792453 percent complete
# Outlier calculation is 95.32232704402516 percent complete
# Outlier calculation is 95.36163522012579 percent complete
# Outlier calculation is 95.40094339622641 percent complete
# Outlier calculation is 95.44025157232704 percent complete
# Outlier calculation is 95.47955974842768 percent complete
# Outlier calculation is 95.51886792452831 percent complete
# Outlier calculation is 95.55817610062893 percent complete
# Outlier calculation is 95.59748427672956 percent complete
# Outlier calculation is 95.63679245283019 percent complete
# Outlier calculation is 95.67610062893081 percent complete
# Outlier calculation is 95.71540880503144 percent complete
# Outlier calculation is 95.75471698113208 percent complete
# Outlier calculation is 95.79402515723271 percent complete
# Outlier calculation is 95.83333333333334 percent complete
# Outlier calculation is 95.87264150943396 percent complete
# Outlier calculation is 95.9119496855346 percent complete
# Outlier calculation is 95.95125786163521 percent complete
# Outlier calculation is 95.99056603773585 percent complete
# Outlier calculation is 96.02987421383648 percent complete
# Outlier calculation is 96.0691823899371 percent complete
# Outlier calculation is 96.10849056603774 percent complete
# Outlier calculation is 96.14779874213836 percent complete
# Outlier calculation is 96.187106918239 percent complete
# Outlier calculation is 96.22641509433963 percent complete
# Outlier calculation is 96.26572327044025 percent complete
# Outlier calculation is 96.30503144654088 percent complete
# Outlier calculation is 96.34433962264151 percent complete
# Outlier calculation is 96.38364779874213 percent complete
# Outlier calculation is 96.42295597484278 percent complete
# Outlier calculation is 96.4622641509434 percent complete
# Outlier calculation is 96.50157232704403 percent complete
# Outlier calculation is 96.54088050314465 percent complete
# Outlier calculation is 96.58018867924528 percent complete
# Outlier calculation is 96.61949685534591 percent complete
# Outlier calculation is 96.65880503144653 percent complete
# Outlier calculation is 96.69811320754717 percent complete
# Outlier calculation is 96.7374213836478 percent complete
# Outlier calculation is 96.77672955974843 percent complete
# Outlier calculation is 96.81603773584906 percent complete
# Outlier calculation is 96.85534591194968 percent complete
# Outlier calculation is 96.89465408805032 percent complete
# Outlier calculation is 96.93396226415094 percent complete
# Outlier calculation is 96.97327044025157 percent complete
# Outlier calculation is 97.0125786163522 percent complete
# Outlier calculation is 97.05188679245283 percent complete
# Outlier calculation is 97.09119496855347 percent complete
# Outlier calculation is 97.13050314465409 percent complete
# Outlier calculation is 97.16981132075472 percent complete
# Outlier calculation is 97.20911949685535 percent complete
# Outlier calculation is 97.24842767295597 percent complete
# Outlier calculation is 97.2877358490566 percent complete
# Outlier calculation is 97.32704402515722 percent complete
# Outlier calculation is 97.36635220125787 percent complete
# Outlier calculation is 97.40566037735849 percent complete
# Outlier calculation is 97.44496855345912 percent complete
# Outlier calculation is 97.48427672955975 percent complete
# Outlier calculation is 97.52358490566037 percent complete
# Outlier calculation is 97.562893081761 percent complete
# Outlier calculation is 97.60220125786164 percent complete
# Outlier calculation is 97.64150943396226 percent complete
# Outlier calculation is 97.6808176100629 percent complete
# Outlier calculation is 97.72012578616352 percent complete
# Outlier calculation is 97.75943396226415 percent complete
# Outlier calculation is 97.79874213836479 percent complete
# Outlier calculation is 97.8380503144654 percent complete
# Outlier calculation is 97.87735849056604 percent complete
# Outlier calculation is 97.91666666666666 percent complete
# Outlier calculation is 97.95597484276729 percent complete
# Outlier calculation is 97.99528301886792 percent complete
# Outlier calculation is 98.03459119496856 percent complete
# Outlier calculation is 98.07389937106919 percent complete
# Outlier calculation is 98.11320754716981 percent complete
# Outlier calculation is 98.15251572327044 percent complete
# Outlier calculation is 98.19182389937107 percent complete
# Outlier calculation is 98.23113207547169 percent complete
# Outlier calculation is 98.27044025157232 percent complete
# Outlier calculation is 98.30974842767296 percent complete
# Outlier calculation is 98.34905660377359 percent complete
# Outlier calculation is 98.38836477987421 percent complete
# Outlier calculation is 98.42767295597484 percent complete
# Outlier calculation is 98.46698113207547 percent complete
# Outlier calculation is 98.5062893081761 percent complete
# Outlier calculation is 98.54559748427673 percent complete
# Outlier calculation is 98.58490566037736 percent complete
# Outlier calculation is 98.62421383647799 percent complete
# Outlier calculation is 98.66352201257862 percent complete
# Outlier calculation is 98.70283018867924 percent complete
# Outlier calculation is 98.74213836477988 percent complete
# Outlier calculation is 98.7814465408805 percent complete
# Outlier calculation is 98.82075471698113 percent complete
# Outlier calculation is 98.86006289308176 percent complete
# Outlier calculation is 98.89937106918238 percent complete
# Outlier calculation is 98.93867924528303 percent complete
# Outlier calculation is 98.97798742138365 percent complete
# Outlier calculation is 99.01729559748428 percent complete
# Outlier calculation is 99.05660377358491 percent complete
# Outlier calculation is 99.09591194968553 percent complete
# Outlier calculation is 99.13522012578616 percent complete
# Outlier calculation is 99.1745283018868 percent complete
# Outlier calculation is 99.21383647798741 percent complete
# Outlier calculation is 99.25314465408806 percent complete
# Outlier calculation is 99.29245283018868 percent complete
# Outlier calculation is 99.33176100628931 percent complete
# Outlier calculation is 99.37106918238993 percent complete
# Outlier calculation is 99.41037735849056 percent complete
# Outlier calculation is 99.4496855345912 percent complete
# Outlier calculation is 99.48899371069182 percent complete
# Outlier calculation is 99.52830188679245 percent complete
# Outlier calculation is 99.56761006289308 percent complete
# Outlier calculation is 99.60691823899371 percent complete
# Outlier calculation is 99.64622641509435 percent complete
# Outlier calculation is 99.68553459119497 percent complete
# Outlier calculation is 99.7248427672956 percent complete
# Outlier calculation is 99.76415094339622 percent complete
# Outlier calculation is 99.80345911949685 percent complete
# Outlier calculation is 99.84276729559748 percent complete
# Outlier calculation is 99.88207547169812 percent complete
# Outlier calculation is 99.92138364779875 percent complete
# Outlier calculation is 99.96069182389937 percent complete
# Outlier calculation is 100.0 percent complete

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_parquet(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\MODEL_training_tle_data.parquet')

def plot_distributions(df):
    cols = ['inclination', 'ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']
    
    fig, axes = plt.subplots(2, 3, figsize=(15, 8))
    axes = axes.flatten()  

    for i, column in enumerate(cols):
        sns.kdeplot(data=df[column], ax=axes[i], fill=True)
        axes[i].set_title(column)
        axes[i].grid(True)

    plt.tight_layout()

    plt.savefig(rf'C:\Users\dk412\Desktop\David\Python Projects\RusSat\outputdistributions_{df}.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

#plot_distributions(df)

# %% [markdown]
# Separate Featuresa from Dataframe for Anomaly Detection

# %%
NORAD_ID_NUM = 32395

samp_df = df[df['NORAD_CAT_ID']==NORAD_ID_NUM]
samp_df = samp_df.sort_values(by='datetime', ascending=False)

orb_df = samp_df[['datetime','inclination','ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']]

orb_df = orb_df.set_index('datetime', drop = True)
orb_df.info(), orb_df.head()

# %% [markdown]
# Anomaly Detection Model

# %%
#################################################################
#               Visualization Class
#################################################################

class TLEVisualizer:
    
    @staticmethod
    def format_timestamps(timestamps, indices=None):
        if indices is not None:
            timestamps = timestamps[indices]
        if not isinstance(timestamps, pd.DatetimeIndex):
            timestamps = pd.DatetimeIndex(timestamps)
        return [ts.strftime('%Y-%m-%d %H:%M') for ts in timestamps]
    
    @staticmethod
    def plot_training_loss(losses: List[float], figsize=(10, 5)):
        plt.figure(figsize=figsize)
        plt.plot(losses, label='Training Loss')
        plt.title('Autoencoder Training Loss Over Time')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.grid(True)
        plt.legend()
        plt.show()
    
    @staticmethod
    def plot_reconstruction_errors(reconstruction_errors: np.ndarray, 
                                 feature_names: List[str],
                                 figsize=(8, 5)):
        plt.figure(figsize=figsize)
        sns.boxplot(data=reconstruction_errors)
        plt.xticks(range(len(feature_names)), feature_names, rotation=45, ha='right')
        plt.title('Distribution of Reconstruction Errors by Feature')
        plt.xlabel('Feature')
        plt.ylabel('Reconstruction Error')
        plt.tight_layout()
        plt.show()
    
    @classmethod
    def plot_anomaly_heatmap(cls, 
                            anomaly_details: Dict, 
                            feature_names: List[str],
                            timestamps,
                            max_samples: int = 50,
                            figsize=(15, 8)):
        anomalous_indices = np.where(np.any(anomaly_details['feature_anomalies'], axis=1))[0]
        
        if len(anomalous_indices) == 0:
            print("No anomalies found to visualize")
            return
        
        if len(anomalous_indices) > max_samples:
            anomalous_indices = anomalous_indices[:max_samples]
        
        z_scores = anomaly_details['z_scores'][anomalous_indices]
        time_labels = cls.format_timestamps(timestamps, anomalous_indices)
        
        plt.figure(figsize=figsize)
        plt.rcParams.update({
            'font.size': 10,
            'axes.titlesize': 12,
            'axes.labelsize': 11,
            'xtick.labelsize': 10,
            'ytick.labelsize': 8,
        })

        sns.heatmap(z_scores, 
                   xticklabels=feature_names,
                   yticklabels=time_labels,
                   cmap='RdYlBu_r',
                   center=0)
        plt.title('Anomaly Z-Scores Heatmap')
        plt.xlabel('Feature')
        plt.ylabel('Timestamp')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()
    
    @staticmethod
    def plot_feature_timeline(data: np.ndarray,
                            anomalies: np.ndarray,
                            feature_names: List[str],
                            timestamps,
                            n_features: int = 6,
                            figsize=(15, 12)):
        if not isinstance(timestamps, pd.DatetimeIndex):
            timestamps = pd.DatetimeIndex(timestamps)
            
        n_features = min(n_features, data.shape[1])
        
        fig = plt.figure(figsize=figsize)
        gs = GridSpec(n_features, 1, figure=fig)
        
        date_formatter = DateFormatter('%Y-%m-%d')
        
        for i in range(n_features):
            ax = fig.add_subplot(gs[i, 0])
            
            ax.plot(timestamps[~anomalies], data[~anomalies, i], 'b.', 
                   alpha=0.5, label='Normal', markersize=4)
            
            if np.any(anomalies):
                ax.plot(timestamps[anomalies], data[anomalies, i], 'r.', 
                       label='Anomaly', alpha=0.7, markersize=6)
            
            ax.set_ylabel(feature_names[i])
            ax.xaxis.set_major_formatter(date_formatter)
            ax.grid(True, alpha=0.3)
            
            if i == 0:
                ax.legend()
            if i == n_features - 1:
                ax.set_xlabel('Time')
            
            plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')
        
        plt.suptitle('Feature Timeline with Anomalies')
        plt.tight_layout()
        plt.show()
    
    @classmethod
    def plot_summary(cls,
                    data: np.ndarray,
                    anomaly_details: Dict,
                    anomalies: np.ndarray,
                    feature_names: List[str],
                    timestamps,
                    losses: List[float]):
        if not isinstance(timestamps, pd.DatetimeIndex):
            timestamps = pd.DatetimeIndex(timestamps)
            
        fig = plt.figure(figsize=(20, 12))
        gs = GridSpec(2, 3, figure=fig)
        
        #Training Loss
        ax1 = fig.add_subplot(gs[0, 0])
        ax1.plot(losses)
        ax1.set_title('Training Loss')
        ax1.set_xlabel('Epoch')
        ax1.set_ylabel('Loss')
        ax1.grid(True, alpha=0.3)
        
        #Reconstruction Error
        ax2 = fig.add_subplot(gs[0, 1:])
        sns.boxplot(data=anomaly_details['reconstruction_errors'], ax=ax2)
        ax2.set_xticklabels(feature_names, rotation=45, ha='right')
        ax2.set_title('Reconstruction Error Distribution')
        ax2.grid(True, alpha=0.3)
        
        #Anomaly Timeline
        ax3 = fig.add_subplot(gs[1, :2])
        ax3.plot(timestamps[~anomalies], np.zeros(np.sum(~anomalies)), 'b.',
                label='Normal', alpha=0.5, markersize=4)
        if np.any(anomalies):
            ax3.plot(timestamps[anomalies], np.ones(np.sum(anomalies)), 'r.',
                    label='Anomaly', alpha=0.7, markersize=6)
        ax3.set_title('Anomaly Timeline')
        ax3.set_ylabel('Anomaly (1) / Normal (0)')
        ax3.set_xlabel('Time')
        ax3.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
        ax3.grid(True, alpha=0.3)
        ax3.legend()
        plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right')
        
        #Feature Distribution
        ax4 = fig.add_subplot(gs[1, 2])
        feature_anomaly_counts = anomaly_details['feature_anomalies'].sum(axis=0)
        ax4.bar(range(len(feature_names)), feature_anomaly_counts)
        ax4.set_xticks(range(len(feature_names)))
        ax4.set_xticklabels(feature_names, rotation=45, ha='right')
        ax4.set_title('Anomalies per Feature')
        ax4.set_ylabel('Count')
        ax4.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()

#################################################################
#               Model Classes
#################################################################

class TLEEncoder(nn.Module):
    def __init__(self, input_dim: int, latent_dim: int):
        super(TLEEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, latent_dim)
        )
        
    def forward(self, x):
        return self.encoder(x)

class TLEDecoder(nn.Module):
    def __init__(self, latent_dim: int, output_dim: int):
        super(TLEDecoder, self).__init__()
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )
        
    def forward(self, x):
        return self.decoder(x)

class TLEAnomalyDetector:
    def __init__(self, input_dim: int, latent_dim: int = 8):
        print(f"Initializing detector with input_dim={input_dim}, latent_dim={latent_dim}")
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")
        
        self.encoder = TLEEncoder(input_dim, latent_dim).to(self.device)
        self.decoder = TLEDecoder(latent_dim, input_dim).to(self.device)
        self.scaler = StandardScaler()
        
    def save_model(self, path: str = f"{NORAD_ID_NUM}anomaly_detector_model"):
#    def save_model(self, path: str = "anomaly_detector_model"):
        os.makedirs(path, exist_ok=True)
        
        torch.save({
            'encoder_state': self.encoder.state_dict(),
            'decoder_state': self.decoder.state_dict(),
            'input_dim': self.input_dim,
            'latent_dim': self.latent_dim
        }, os.path.join(path, f'{NORAD_ID_NUM}_model.pt'))
        
        joblib.dump(self.scaler, os.path.join(path, 'scaler.pkl'))
        
        print(f"Model saved to {path}")
    
    @classmethod
    def load_model(cls, path: str = f"{NORAD_ID_NUM}anomaly_detector_model") -> 'TLEAnomalyDetector':
        checkpoint = torch.load(os.path.join(path, f'{NORAD_ID_NUM}_model.pt'))
        
        detector = cls(input_dim=checkpoint['input_dim'], 
                     latent_dim=checkpoint['latent_dim'])
        
        detector.encoder.load_state_dict(checkpoint['encoder_state'])
        detector.decoder.load_state_dict(checkpoint['decoder_state'])
        
        detector.scaler = joblib.load(os.path.join(path, 'scaler.pkl'))
        
        detector.encoder.eval()
        detector.decoder.eval()
        
        print(f"Model loaded from {path}")
        return detector
        
    def visualize_results(self, data: np.ndarray, 
                         anomalies: np.ndarray,
                         anomaly_details: Dict,
                         feature_names: List[str],
                         timestamps: pd.DatetimeIndex,
                         losses: List[float]):
        visualizer = TLEVisualizer()
        
        print("Generating visualization summary...")
        visualizer.plot_summary(data, anomaly_details, anomalies, 
                              feature_names, timestamps, losses)
        
        print("\nGenerating detailed visualizations...")
        visualizer.plot_training_loss(losses)
        visualizer.plot_reconstruction_errors(anomaly_details['reconstruction_errors'], 
                                           feature_names)
        visualizer.plot_anomaly_heatmap(anomaly_details, feature_names, timestamps)
        visualizer.plot_feature_timeline(data, anomalies, feature_names, timestamps)
        
    def _validate_input_data(self, data: np.ndarray) -> None:
        if not isinstance(data, np.ndarray):
            raise TypeError(f"Expected numpy array, got {type(data)}")
        
        if len(data.shape) != 2:
            raise ValueError(f"Expected 2D array, got shape {data.shape}")
            
        if data.shape[1] != self.input_dim:
            raise ValueError(f"Expected {self.input_dim} features, got {data.shape[1]}")
            
        if np.isnan(data).any():
            raise ValueError("Input data contains NaN values")
            
        if np.isinf(data).any():
            raise ValueError("Input data contains infinite values")

    def train(self, data: np.ndarray, epochs: int = 150, batch_size: int = 32) -> List[float]:
        print(f"Starting training with data shape: {data.shape}")
        self._validate_input_data(data)
        
        scaled_data = self.scaler.fit_transform(data)
        train_data = torch.FloatTensor(scaled_data).to(self.device)
        
        optimizer = optim.Adam(list(self.encoder.parameters()) + 
                             list(self.decoder.parameters()))
        criterion = nn.MSELoss(reduction='none')
        losses = []
        
        n_batches = (len(train_data) + batch_size - 1) // batch_size
        print(f"Training with {n_batches} batches per epoch")
        
        for epoch in range(epochs):
            total_loss = 0
            for i in range(0, len(train_data), batch_size):
                batch = train_data[i:min(i + batch_size, len(train_data))]
                
                latent = self.encoder(batch)
                reconstructed = self.decoder(latent)
                
                loss = criterion(reconstructed, batch).mean()
                
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                total_loss += loss.item()
            
            avg_loss = total_loss / n_batches
            losses.append(avg_loss)
            
            if (epoch + 1) % 10 == 0:
                print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.6f}")
                
        return losses
    
    def detect_anomalies(self, data: np.ndarray, threshold_sigma: float = 3) -> Tuple[np.ndarray, Dict]:
        print(f"Detecting anomalies in data with shape: {data.shape}")
        self._validate_input_data(data)
        
        scaled_data = self.scaler.transform(data)
        test_data = torch.FloatTensor(scaled_data).to(self.device)
        
        with torch.no_grad():
            latent = self.encoder(test_data)
            reconstructed = self.decoder(latent)
        
        reconstruction_errors = torch.abs(test_data - reconstructed)
        reconstruction_errors = reconstruction_errors.cpu().numpy()
        error_mean = np.mean(reconstruction_errors, axis=0)
        error_std = np.std(reconstruction_errors, axis=0)
        error_std = np.where(error_std == 0, 1e-10, error_std)
        
        z_scores = (reconstruction_errors - error_mean) / error_std
        anomalies = np.any(np.abs(z_scores) > threshold_sigma, axis=1)
        
        anomaly_details = {
            'z_scores': z_scores,
            'feature_anomalies': np.abs(z_scores) > threshold_sigma,
            'reconstruction_errors': reconstruction_errors
        }
        
        print(f"Found {np.sum(anomalies)} anomalous samples")
        return anomalies, anomaly_details
    
    def explain_anomalies(self, anomaly_details: Dict, feature_names: List[str] = None) -> List[Dict]:
        if feature_names is None:
            feature_names = [f"Feature_{i}" for i in range(anomaly_details['z_scores'].shape[1])]
        
        if len(feature_names) != anomaly_details['z_scores'].shape[1]:
            raise ValueError(f"Expected {anomaly_details['z_scores'].shape[1]} feature names, got {len(feature_names)}")
            
        print(f"Generating explanations for shape {anomaly_details['z_scores'].shape}")
        explanations = []
        
        for i in range(len(anomaly_details['z_scores'])):
            if np.any(anomaly_details['feature_anomalies'][i]):
                anomalous_features = []
                for j, is_anomaly in enumerate(anomaly_details['feature_anomalies'][i]):
                    if is_anomaly:
                        anomalous_features.append({
                            'feature': feature_names[j],
                            'z_score': float(anomaly_details['z_scores'][i, j]),  
                            'reconstruction_error': float(anomaly_details['reconstruction_errors'][i, j])
                        })
                
                if anomalous_features:
                    explanations.append({
                        'sample_index': int(i),  
                        'anomalous_features': anomalous_features
                    })
                    
        print(f"Generated {len(explanations)} anomaly explanations")
        return explanations

def run_anomaly_detection_pipeline(df: pd.DataFrame, 
                                 feature_names: List[str] = None,
                                 model_path: str = None,
                                 should_train: bool = False):

    try:
        if not isinstance(df.index, pd.DatetimeIndex):
            df.index = pd.to_datetime(df.index)
            
        data = df.values
        timestamps = df.index
        input_dim = data.shape[1]
        
        if should_train:
            print("Training new model...")
            detector = TLEAnomalyDetector(input_dim=input_dim)
            losses = detector.train(data, epochs=150)
            
            if model_path:
                detector.save_model(model_path)
        else:
            if not model_path:
                raise ValueError("model_path must be provided when should_train=False")
            print("Loading existing model...")
            detector = TLEAnomalyDetector.load_model(model_path)
        
        print("Detecting anomalies...")
        anomalies, anomaly_details = detector.detect_anomalies(data, 3)
        
        if feature_names is None:
            feature_names = df.columns.tolist()
            
        print("Generating explanations...")
        explanations = detector.explain_anomalies(anomaly_details, feature_names)
        
        print("Generating visualizations...")
        detector.visualize_results(data, anomalies, anomaly_details, 
                                 feature_names, timestamps, 
                                 losses if should_train else [])
        
        return detector, anomalies, explanations, timestamps, anomaly_details
        
    except Exception as e:
        print(f"Error during anomaly detection: {str(e)}")
        raise

# %%
feature_names = list(orb_df)

detector, anomalies, explanations, timestamps, anomaly_details = run_anomaly_detection_pipeline(
    orb_df,
    feature_names=feature_names,
    model_path=r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model",
    should_train=True
)

anom_dts_idx = []
anom_dict = {}
print(f"\nFound {sum(anomalies)} anomalous samples")
for exp in explanations:
    print(f"\nAnomaly at sample {exp['sample_index']} on {orb_df.index[exp['sample_index']].strftime('%Y-%m-%d')}:")
    anom_dts_idx.append(exp['sample_index'])

    feature_lst =[]

    for feat in exp['anomalous_features']:
        print(f"- {feat['feature']}: z-score = {feat['z_score']:.2f}")
        feature_lst.append(feat['feature'])

    anom_dict[exp['sample_index']] = feature_lst

# %% [markdown]
# Add Anomaly Info to Dataframe

# %%
#samp_df['anomaly'] = [1 if i in anom_dts_idx else 0 for i in range(len(samp_df))]
full_df = samp_df.copy(deep=False)
#full_df['date'] = full_df.index
#full_df['date'] = pd.to_datetime(full_df['date']).dt.date
full_df.reset_index(inplace=True, drop = True)

all_features = set()
for features_list in anom_dict.values():
    all_features.update(features_list)

anom_df = pd.DataFrame(0, 
                      index=anom_dict.keys(),
                      columns=[f'anom_{feat}' for feat in sorted(all_features)])

for key, features in anom_dict.items():
    anom_df.loc[key, [f'anom_{feat}' for feat in features]] = 1

full_df = pd.concat([full_df, anom_df], axis=1)

anom_cols = full_df.columns.str.startswith('anom')
anom_data = full_df.iloc[:, anom_cols]
full_df['anom_count'] = anom_data.sum(axis=1)

full_df = full_df.fillna(0)

# %%
full_df.iloc[90:95]

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scattergeo(
    lon=full_df['x'],  
    lat=full_df['y'],  
    mode='markers',
    marker=dict(
        size=5,
        color=['red' if count > 0 else 'blue' for count in full_df['anom_count']],
        opacity=0.8,
        symbol='circle'
    ),
    text=full_df['anom_count'].apply(lambda x: f'Anomaly Count: {x}'),
    name='Satellites'
))

fig.update_layout(
    title='Global Satellite Positions',
    geo=dict(
        projection_type='orthographic',  # 3D globe view
        showland=True,
        showocean=True,
        showcoastlines=True,
        showcountries=True,
        oceancolor='rgb(204, 229, 255)',
        landcolor='rgb(243, 243, 243)',
        coastlinecolor='rgb(80, 80, 80)',
        countrycolor='rgb(80, 80, 80)',
        bgcolor='rgba(255, 255, 255, 0)',
        framecolor='rgba(255, 255, 255, 0)',
        showframe=False
    ),
    paper_bgcolor='rgba(255, 255, 255, 1)',
    plot_bgcolor='rgba(255, 255, 255, 1)',
    margin=dict(l=0, r=0, t=30, b=0)
)

fig.show()

# %% [markdown]
# Inference

# %%
combat_data = pd.read_parquet(r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\DEV_combat_tle_df.parquet")
tle_cols = ['datetime', 'catalog_number']
combat_data = combat_data.drop_duplicates(subset=tle_cols)

# %%
combat_data['datetime'].max()

# %%
combat_data['catalog_number'] = combat_data['catalog_number'].astype(int)
satcat_df['NORAD_CAT_ID'] = satcat_df['NORAD_CAT_ID'].astype(int)

combat_data = combat_data.merge(
    satcat_df[['NORAD_CAT_ID', 'OBJECT_TYPE', 'SATNAME', 'SITE']], 
    left_on='catalog_number',
    right_on='NORAD_CAT_ID',
    how='left'
)

combat_data = combat_data.drop('catalog_number', axis=1)

combat_data = combat_data.merge(
    ucs_df[['NORAD Number', 'Operator/Owner', 'Users', 'Purpose']], 
    left_on='NORAD_CAT_ID',
    right_on='NORAD Number',
    how='left'
)

combat_data = combat_data.drop('NORAD Number', axis=1)

# %%
combat_samp_df = combat_data[combat_data['NORAD_CAT_ID']==NORAD_ID_NUM]
combat_samp_df = combat_samp_df.sort_values(by='datetime', ascending=False)

combat_orb_df = combat_samp_df[['datetime','mean_motion_dot','mean_motion_ddot','inclination','ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']]

combat_orb_df = combat_orb_df.set_index('datetime', drop = True)
combat_orb_df.info(), combat_orb_df.head()

# %%
feature_names = list(combat_orb_df)

# Load and use on new data
detector, anomalies, explanations, timestamps, anomaly_details = run_anomaly_detection_pipeline(
    combat_orb_df,
    feature_names=feature_names,
    model_path=r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model",
    should_train=False
)
 
anom_dts_idx = []
anom_dict = {}
print(f"\nFound {sum(anomalies)} anomalous samples")
for exp in explanations:
    print(f"\nAnomaly at sample {exp['sample_index']} on {combat_orb_df.index[exp['sample_index']].strftime('%Y-%m-%d')}:")
    anom_dts_idx.append(exp['sample_index'])

    feature_lst =[]

    for feat in exp['anomalous_features']:
        print(f"- {feat['feature']}: z-score = {feat['z_score']:.2f}")
        feature_lst.append(feat['feature'])

    anom_dict[exp['sample_index']] = feature_lst

# %%
#samp_df['anomaly'] = [1 if i in anom_dts_idx else 0 for i in range(len(samp_df))]
combat_full_df = combat_samp_df.copy(deep=False)
#combat_full_df['date'] = combat_full_df.index
#combat_full_df['date'] = pd.to_datetime(combat_full_df['date']).dt.date
combat_full_df.reset_index(inplace=True, drop = True)

all_features = set()
for features_list in anom_dict.values():
    all_features.update(features_list)

combat_anom_df = pd.DataFrame(0, 
                      index=anom_dict.keys(),
                      columns=[f'anom_{feat}' for feat in sorted(all_features)])

for key, features in anom_dict.items():
    combat_anom_df.loc[key, [f'anom_{feat}' for feat in features]] = 1

combat_full_df = pd.concat([combat_full_df, combat_anom_df], axis=1)

anom_cols = combat_full_df.columns.str.startswith('anom')
anom_data = combat_full_df.iloc[:, anom_cols]
combat_full_df['anom_count'] = anom_data.sum(axis=1)

combat_full_df = combat_full_df.fillna(0)

# %%
anomalies_df = combat_full_df.loc[combat_full_df['anom_count'] > 0]

# %%
anomalies_df['anom_count'].value_counts()

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scattergeo(
    lon=anomalies_df['x'],  
    lat=anomalies_df['y'],  
    mode='markers',
    marker=dict(
        size=5,
        color=['red' if count > 0 else 'blue' for count in anomalies_df['anom_count']],
        opacity=0.8,
        symbol='circle'
    ),
    text=full_df['anom_count'].apply(lambda x: f'Anomaly Count: {x}'),
    name='Satellites'
))

fig.update_layout(
    title='Global Satellite Positions',
    geo=dict(
        projection_type='orthographic',  # 3D globe view
        showland=True,
        showocean=True,
        showcoastlines=True,
        showcountries=True,
        oceancolor='rgb(204, 229, 255)',
        landcolor='rgb(243, 243, 243)',
        coastlinecolor='rgb(80, 80, 80)',
        countrycolor='rgb(80, 80, 80)',
        bgcolor='rgba(255, 255, 255, 0)',
        framecolor='rgba(255, 255, 255, 0)',
        showframe=False
    ),
    paper_bgcolor='rgba(255, 255, 255, 1)',
    plot_bgcolor='rgba(255, 255, 255, 1)',
    margin=dict(l=0, r=0, t=30, b=0)
)

fig.show()

# %%
##################################################################################################################
#                                            PROD CODE - ANOM DETECT
###################################################################################################################

import pandas as pd
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from collections import Counter
import numpy as np
from typing import Tuple, List, Dict
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from matplotlib.dates import DateFormatter
import os
import joblib
import plotly.graph_objects as go
import sys
sys.path.append(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code')
from helpers import *
from skyfield.api import load, EarthSatellite
from datetime import datetime, timezone
import numpy as np


#################################################################
#               Model Save and Load
#################################################################

def save_model(self, path: str = f"{e}_anomaly_detector_model"):
#    def save_model(self, path: str = "anomaly_detector_model"):
    os.makedirs(path, exist_ok=True)
    
    torch.save({
        'encoder_state': self.encoder.state_dict(),
        'decoder_state': self.decoder.state_dict(),
        'input_dim': self.input_dim,
        'latent_dim': self.latent_dim
    }, os.path.join(path, f'{e}_model.pt'))
    
    joblib.dump(self.scaler, os.path.join(path, 'scaler.pkl'))
    
    print(f"Model saved to {path}")

@classmethod
def load_model(cls, path: str = f"{e}_anomaly_detector_model") -> 'TLEAnomalyDetector':
    checkpoint = torch.load(os.path.join(path, f'{e}_model.pt'))
    
    detector = cls(input_dim=checkpoint['input_dim'], 
                    latent_dim=checkpoint['latent_dim'])
    
    detector.encoder.load_state_dict(checkpoint['encoder_state'])
    detector.decoder.load_state_dict(checkpoint['decoder_state'])
    
    detector.scaler = joblib.load(os.path.join(path, 'scaler.pkl'))
    
    detector.encoder.eval()
    detector.decoder.eval()
    
    print(f"Model loaded from {path}")
    return detector
        

##################################################################
#                      Data Preprocessing
###################################################################

def data_build_pipeline(parquet_file):
    df = pd.read_parquet(parquet_file)
    tle_cols = ['datetime', 'catalog_number']
    df = df.drop_duplicates(subset=tle_cols)

    ucs_df = pd.read_csv(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\UCS-Satellite-Database 5-1-2023.csv',encoding='latin-1')

    with open(r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\CIS_satcat.pkl", 'rb') as f:
        satcat = pickle.load(f, encoding='latin1')
    
    satcat_df = pd.DataFrame(satcat)

    df['catalog_number'] = df['catalog_number'].astype(int)
    satcat_df['NORAD_CAT_ID'] = satcat_df['NORAD_CAT_ID'].astype(int)

    df = df.merge(
        satcat_df[['NORAD_CAT_ID', 'OBJECT_TYPE', 'SATNAME', 'SITE']], 
        left_on='catalog_number',
        right_on='NORAD_CAT_ID',
        how='left'
    )

    df = df.drop('catalog_number', axis=1)

    df = df.merge(
        ucs_df[['NORAD Number', 'Operator/Owner', 'Users', 'Purpose']], 
        left_on='NORAD_CAT_ID',
        right_on='NORAD Number',
        how='left'
    )

    df = df.drop('NORAD Number', axis=1)

    return df

##################################################################
#                      Model Train and Fetch
###################################################################
def develop_fetch_model(df, NORAD_ID_NUM, model_training):
    samp_df = df[df['NORAD_CAT_ID']==NORAD_ID_NUM]
    samp_df = samp_df.sort_values(by='datetime', ascending=False)

    orb_df = samp_df[['datetime','mean_motion_dot','mean_motion_ddot','inclination','ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']]

    orb_df = orb_df.set_index('datetime', drop = True)
    orb_df.info(), orb_df.head()

    feature_names = list(orb_df)

    if model_training:
        detector, anomalies, explanations, timestamps, anomaly_details = run_anomaly_detection_pipeline(
            orb_df,
            feature_names=feature_names,
            model_path=r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model",
            should_train=True
        )
    else:
        detector, anomalies, explanations, timestamps, anomaly_details = run_anomaly_detection_pipeline(
            orb_df,
            feature_names=feature_names,
            model_path=r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model",
            should_train=False
        )

    anom_dts_idx = []
    anom_dict = {}
    print(f"\nFound {sum(anomalies)} anomalous samples")
    for exp in explanations:
        print(f"\nAnomaly at sample {exp['sample_index']} on {orb_df.index[exp['sample_index']].strftime('%Y-%m-%d')}:")
        anom_dts_idx.append(exp['sample_index'])

        feature_lst =[]

        for feat in exp['anomalous_features']:
            print(f"- {feat['feature']}: z-score = {feat['z_score']:.2f}")
            feature_lst.append(feat['feature'])

        anom_dict[exp['sample_index']] = feature_lst

    full_df = samp_df.copy(deep=False)
    full_df.reset_index(inplace=True, drop = True)

    all_features = set()
    for features_list in anom_dict.values():
        all_features.update(features_list)

    anom_df = pd.DataFrame(0, 
                        index=anom_dict.keys(),
                        columns=[f'anom_{feat}' for feat in sorted(all_features)])

    for key, features in anom_dict.items():
        anom_df.loc[key, [f'anom_{feat}' for feat in features]] = 1

    full_df = pd.concat([full_df, anom_df], axis=1)

    anom_cols = full_df.columns.str.startswith('anom')
    anom_data = full_df.iloc[:, anom_cols]
    full_df['anom_count'] = anom_data.sum(axis=1)

    full_df = full_df.fillna(0)

    fig = go.Figure()

    fig.add_trace(go.Scattergeo(
        lon=full_df['x'],  
        lat=full_df['y'],  
        mode='markers',
        marker=dict(
            size=5,
            color=['red' if count > 0 else 'blue' for count in full_df['anom_count']],
            opacity=0.8,
            symbol='circle'
        ),
        text=full_df['anom_count'].apply(lambda x: f'Anomaly Count: {x}'),
        name='Satellites'
    ))

    fig.update_layout(
        title='Training Data Satellite Positions',
        geo=dict(
            projection_type='orthographic',  # 3D globe view
            showland=True,
            showocean=True,
            showcoastlines=True,
            showcountries=True,
            oceancolor='rgb(204, 229, 255)',
            landcolor='rgb(243, 243, 243)',
            coastlinecolor='rgb(80, 80, 80)',
            countrycolor='rgb(80, 80, 80)',
            bgcolor='rgba(255, 255, 255, 0)',
            framecolor='rgba(255, 255, 255, 0)',
            showframe=False
        ),
        paper_bgcolor='rgba(255, 255, 255, 1)',
        plot_bgcolor='rgba(255, 255, 255, 1)',
        margin=dict(l=0, r=0, t=30, b=0)
    )

    fig.show()

    return full_df

# %%
df = data_build_pipeline(r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\DEV_training_tle_df.parquet")
inf_df = data_build_pipeline(r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\DEV_combat_tle_df.parquet")

results_train_df = pd.DataFrame()
results_inf_df = pd.DataFrame()

for e in df['NORAD_CAT_ID'].unique():
    full_train_df = develop_training_model(df, e, True)
    full_inf_df = develop_training_model(inf_df, e, False)
    results_train_df = pd.concat([results_train_df, full_train_df], ignore_index = True)
    print("\nresults_train_df:\t", results_train_df.shape)
    results_inf_df = pd.concat([results_inf_df, full_inf_df], ignore_index = True)
    print("\nresults_inf_df:\t", results_inf_df.shape)
