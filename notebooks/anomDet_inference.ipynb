# %%
import pandas as pd
import os
import sys

sys.path.append(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code')
from inf_helpers import *

# %%
df = pd.read_parquet(r'C:\Users\dk412\Desktop\David\Python Projects\RusSat\dataout_HPC\MODEL_inference_tle_data.parquet')

# %%
def build_anom_model(NORAD_ID_NUM, type):

    os.makedirs(rf"C:\Users\dk412\Desktop\David\Python Projects\RusSat\output\{type}_plots\plots_{type}_{NORAD_ID_NUM}", exist_ok=True)

    samp_df = df[df['NORAD_CAT_ID']==NORAD_ID_NUM]
    samp_df = samp_df.sort_values(by='datetime', ascending=False)
    orb_df = samp_df[['datetime','inclination','ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']]
    orb_df = orb_df.set_index('datetime', drop = True)
    
    plot_save_dir = rf"C:\Users\dk412\Desktop\David\Python Projects\RusSat\output\{type}_plots\plots_{type}_{NORAD_ID_NUM}"
    
    feature_names = list(orb_df)
    
    detector, anomalies, explanations, timestamps, anomaly_details = run_anomaly_detection_pipeline(
        orb_df,
        feature_names=feature_names,
        model_path=r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model",
        should_train=False,
        NORAD_ID_NUM=NORAD_ID_NUM,  
        plot_save_dir=plot_save_dir  
    )
    
    return orb_df, detector, anomalies, explanations, samp_df   

unique_ids = df['NORAD_CAT_ID'].unique()
total_sats = len(unique_ids)

all_orbital_features = ['inclination', 'ra_of_asc_node', 'eccentricity', 'arg_of_perigee', 'mean_anomaly', 'mean_motion']
anom_columns = [f'anom_{feat}' for feat in all_orbital_features]

type_nm = 'inference'

for count, x in enumerate(unique_ids, 1):
    orb_df, detector, anomalies, explanations, samp_df = build_anom_model(x,type_nm)
    
    anom_dict = {exp['sample_index']: [feat['feature'] for feat in exp['anomalous_features']] for exp in explanations}  

    full_df = samp_df.copy(deep=False)
    full_df.reset_index(inplace=True, drop = True)

    all_features = set().union(*[set(features) for features in anom_dict.values()]) 
    
    anom_df = pd.DataFrame(0, 
                        index=anom_dict.keys(),
                        columns=anom_columns)


    for key, features in anom_dict.items():
        anom_df.loc[key, [f'anom_{feat}' for feat in features]] = 1
    

    full_df = full_df.join(anom_df, how='left')

    for col in anom_columns:
        if col not in full_df.columns:
            full_df[col] = 0

    full_df['anom_count'] = full_df.filter(like='anom_').sum(axis=1)
    full_df = full_df.fillna(0)

    mode = 'w' if count == 1 else 'a'
    header = count == 1
    full_df.to_csv(fr'C:\Users\dk412\Desktop\David\Python Projects\RusSat\output\anom_df_{type_nm}_all_sats.csv', mode=mode, header=header, index=False)
    
    progress = count/df['NORAD_CAT_ID'].nunique()*100
    print(f"\nModel number {count} out of {df['NORAD_CAT_ID'].nunique()} complete. Progress: {progress:.3f}% done\n")

    del full_df, orb_df, detector, anomalies, explanations, samp_df
    del anom_df, anom_dict
# Out:
# Loading existing model...
# Initializing detector with input_dim=6, latent_dim=4
# Using device: cpu
# Model loaded from C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model
# Detecting anomalies...
# Detecting anomalies in data with shape: (337, 6)
# Found 0 anomalous samples
# Generating explanations...
# Generating explanations for shape (337, 6)
# Generated 0 anomaly explanations
# Generating visualizations...
# Generating visualization summary...
# C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:163: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(feature_names, rotation=45, ha='right')
# Generating detailed visualizations...
# No anomalies found to visualize
# C:\Users\dk412\AppData\Local\Temp\ipykernel_21500\4197196965.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   full_df = full_df.fillna(0)
# C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:163: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(feature_names, rotation=45, ha='right')
# Model number 1 out of 2555 complete. Progress: 0.039% done
#
# Loading existing model...
# Initializing detector with input_dim=6, latent_dim=4
# Using device: cpu
# Model loaded from C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model
# Detecting anomalies...
# Detecting anomalies in data with shape: (292, 6)
# Found 0 anomalous samples
# Generating explanations...
# Generating explanations for shape (292, 6)
# Generated 0 anomaly explanations
# Generating visualizations...
# Generating visualization summary...
#
# Generating detailed visualizations...
# No anomalies found to visualize
# C:\Users\dk412\AppData\Local\Temp\ipykernel_21500\4197196965.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   full_df = full_df.fillna(0)
# Model number 2 out of 2555 complete. Progress: 0.078% done
#
# Loading existing model...
# Initializing detector with input_dim=6, latent_dim=4
# Using device: cpu
# Model loaded from C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model
# Detecting anomalies...
# Detecting anomalies in data with shape: (379, 6)
# Found 7 anomalous samples
# Generating explanations...
# Generating explanations for shape (379, 6)
# Generated 7 anomaly explanations
# Generating visualizations...
# Generating visualization summary...
# C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:163: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(feature_names, rotation=45, ha='right')
# Generating detailed visualizations...
# C:\Users\dk412\AppData\Local\Temp\ipykernel_21500\4197196965.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   full_df = full_df.fillna(0)
# C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:163: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(feature_names, rotation=45, ha='right')
# Model number 3 out of 2555 complete. Progress: 0.117% done
#
# Loading existing model...
# Initializing detector with input_dim=6, latent_dim=4
# Using device: cpu
# Model loaded from C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model
# Detecting anomalies...
# Detecting anomalies in data with shape: (399, 6)
# Found 0 anomalous samples
# Generating explanations...
# Generating explanations for shape (399, 6)
# Generated 0 anomaly explanations
# Generating visualizations...
# Generating visualization summary...
#
# Generating detailed visualizations...
# No anomalies found to visualize
# C:\Users\dk412\AppData\Local\Temp\ipykernel_21500\4197196965.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   full_df = full_df.fillna(0)
# C:\Users\dk412\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:163: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(feature_names, rotation=45, ha='right')
# Model number 4 out of 2555 complete. Progress: 0.157% done
#
# Loading existing model...
# Initializing detector with input_dim=6, latent_dim=4
# Using device: cpu
# Model loaded from C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model
# Detecting anomalies...
# Detecting anomalies in data with shape: (356, 6)
# Found 0 anomalous samples
# Generating explanations...
# Generating explanations for shape (356, 6)
# Generated 0 anomaly explanations
# Generating visualizations...
# Generating visualization summary...
#
# Generating detailed visualizations...
# No anomalies found to visualize
# C:\Users\dk412\AppData\Local\Temp\ipykernel_21500\4197196965.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   full_df = full_df.fillna(0)
# Model number 5 out of 2555 complete. Progress: 0.196% done
#
# Loading existing model...
# Error during anomaly detection: [Errno 2] No such file or directory: 'C:\\Users\\dk412\\Desktop\\David\\Python Projects\\RusSat\\anomaly_model\\1571_model.pt'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 34
#      31 type_nm = 'inference'
#      33 for count, x in enumerate(unique_ids, 1):
# ---> 34     orb_df, detector, anomalies, explanations, samp_df = build_anom_model(x,type_nm)
#      36     anom_dict = {exp['sample_index']: [feat['feature'] for feat in exp['anomalous_features']] for exp in explanations}
#      38     full_df = samp_df.copy(deep=False)
#
# Cell In[5], line 14, in build_anom_model(NORAD_ID_NUM, type)
#      10 plot_save_dir = rf"C:\Users\dk412\Desktop\David\Python Projects\RusSat\output\{type}_plots\plots_{type}_{NORAD_ID_NUM}"
#      12 feature_names = list(orb_df)
# ---> 14 detector, anomalies, explanations, timestamps, anomaly_details = run_anomaly_detection_pipeline(
#      15     orb_df,
#      16     feature_names=feature_names,
#      17     model_path=r"C:\Users\dk412\Desktop\David\Python Projects\RusSat\anomaly_model",
#      18     should_train=False,
#      19     NORAD_ID_NUM=NORAD_ID_NUM,
#      20     plot_save_dir=plot_save_dir
#      21 )
#      23 return orb_df, detector, anomalies, explanations, samp_df
#
# File ~\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:467, in run_anomaly_detection_pipeline(df, feature_names, model_path, should_train, NORAD_ID_NUM, plot_save_dir)
#     465         raise ValueError("model_path must be provided when should_train=False")
#     466     print("Loading existing model...")
# --> 467     detector = TLEAnomalyDetector.load_model(model_path, NORAD_ID_NUM)
#     469 print("Detecting anomalies...")
#     470 anomalies, anomaly_details = detector.detect_anomalies(data, 3)
#
# File ~\Desktop\David\Python Projects\RusSat\prod_code\inf_helpers2.py:289, in TLEAnomalyDetector.load_model(cls, path, NORAD_ID_NUM)
#     287 @classmethod
#     288 def load_model(cls, path: str, NORAD_ID_NUM: int) -> 'TLEAnomalyDetector':
# --> 289     checkpoint = torch.load(os.path.join(path, f'{NORAD_ID_NUM}_model.pt'))
#     291     detector = cls(input_dim=checkpoint['input_dim'],
#     292                  latent_dim=checkpoint['latent_dim'])
#     294     detector.encoder.load_state_dict(checkpoint['encoder_state'])
#
# File c:\Users\dk412\.conda\envs\satdet_env\lib\site-packages\torch\serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File c:\Users\dk412\.conda\envs\satdet_env\lib\site-packages\torch\serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File c:\Users\dk412\.conda\envs\satdet_env\lib\site-packages\torch\serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\dk412\\Desktop\\David\\Python Projects\\RusSat\\anomaly_model\\1571_model.pt'
